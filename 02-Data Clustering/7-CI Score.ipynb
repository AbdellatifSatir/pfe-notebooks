# %%
import pandas as pd 
import numpy as np
import spacy as sp

nlp = sp.load('en_core_web_sm')
nlp_lg = sp.load('en_core_web_lg')

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Import data

# %%
full_data_clustered = pd.read_csv('full_data_clustered.csv')
full_data_clustered = full_data_clustered.replace(np.nan,'None')

# %%
full_data_clustered.head(2)
# Out:
#              CVE ID Publish Date Update Date  \
# 0  CVE-2019-1020019   2019-07-29  2019-07-31
# 1  CVE-2019-1020018   2019-07-29  2022-04-18
#
#    Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 0                            22413.0      1      79                   XSS
# 1                             3011.0      2     287               Unknown
#
#    Score  Access Complexity Authentication    Conf.   Integ.    Avail  \
# 0    4.3  Remote     Medium   Not required     None  Partial     None
# 1    7.5  Remote        Low   Not required  Partial  Partial  Partial
#
#    cluster                                        CVE Summary  \
# 0        0      invenio-previewer before 1.0.0a12 allows XSS.
# 1        2  Discourse before 2.3.0 and 2.4.x before 2.4.0....
#
#                                   Vulnerability Name  \
# 0  Failure to Preserve Web Page Structure ('Cross...
# 1                            Improper Authentication
#
#                            Vulnerability Description  \
# 0       The software does not sufficiently valida...
# 1       When an actor claims to have a given iden...
#
#                                           CLEAN TEXT  cluster_2
# 0  failure preserve web page structure cross site...          1
# 1  improper authentication actor claim give ident...          2

# %% [markdown]
# ## Test Similarity
#
# - To classify text based on similarity to the term "critical infrastructure," you can use word embeddings to measure the semantic similarity between the text and the target term. One common way to do this is by using pre-trained word embeddings like Word2Vec or GloVe
# - spaCy provides a Word2Vec-based word embeddings model called "en_core_web_lg," which is trained on large corpora and includes word vectors for over 1 million unique words.
# - Sentence embeddings are useful when you want to compare the similarity or meaning of entire sentences or documents.

# %%
s1 = full_data_clustered['CLEAN TEXT'][1]
s2 = 'critical infrastructure'

doc1 = nlp(s1)
doc2 = nlp(s2)

doc1.similarity(doc2)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_11700\1899074979.py:7: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   doc1.similarity(doc2)
# 0.42953072988705027

# %%
doc1 = nlp_lg(s1)
doc2 = nlp_lg(s2)

doc1.similarity(doc2)
# Out:
# 0.6251714899710745

# %%
def similarity(text):
    docc = nlp_lg(text)
    ci = nlp_lg('critical infrastructure')
    return docc.similarity(ci)

# %%
sim = full_data_clustered.sample(5)
sim['CI SCORE'] = sim['CLEAN TEXT'].apply(similarity)
sim[['CVE ID','index','CLEAN TEXT','CI SCORE']]
# Out:
#                CVE ID  index  \
# 19498   CVE-2020-8236  19499
# 9330    CVE-2019-0180   9331
# 15468  CVE-2020-16269  15469
# 44367  CVE-2022-40944  44368
# 32472  CVE-2021-31231  32473
#
#                                               CLEAN TEXT  CI SCORE
# 19498  improper authentication actor claim give ident...  0.590032
# 9330   insufficiently protected credential weakness o...  0.747610
# 15468  improper input validation product validate inc...  0.732623
# 44367  improper sanitization special elements sql com...  0.718948
# 32472  improper input validation product validate inc...  0.682499

# %% [markdown]
# ## Apply to all data
# - Word embeddings capture the semantic meaning of words by representing them as dense, low-dimensional vectors. Popular word embedding models include Word2Vec, GloVe, and FastText.
# - Word embeddings capture semantic relationships, but they require pre-training on large corpora and may not work well for rare or out-of-vocabulary words.
# - Docs : https://spacy.io/usage/linguistic-features#vectors-similarity

# %%
def similarity(text):
    docc = nlp_lg(text)
    ci = nlp_lg('critical infrastructure')
    return docc.similarity(ci)


def chunks(csv_input_name, input_column, output_column, csv_output_name, func, chunksize=10000):
    i = 1
    df = pd.DataFrame()
    for reader in pd.read_csv(csv_input_name, chunksize=chunksize):
        reader[output_column] = reader[input_column].apply(func)
        print('chunk',i,'\n ',reader,'\n=============================\n')
        df = pd.concat([df,reader] , ignore_index=True)
        i = i+1
    return df.to_csv(csv_output_name , index=False)

# %%
# chunks(csv_input_name = 'full_data_clustered.csv',
#        input_column = 'CLEAN TEXT',
#        output_column = 'CI SCORE',
#        csv_output_name = 'full_data_clustered_ssim.csv',
#        func = similarity,
#        chunksize = 10000
#       )
# =~30 min

# %% [markdown]
# ## Final data

# %%
full_data_clustered_ssim = pd.read_csv('full_data_clustered_ssim.csv')

# %%
full_data_clustered_ssim.head(2)
# Out:
#              CVE ID Publish Date Update Date  \
# 0  CVE-2019-1020019   2019-07-29  2019-07-31
# 1  CVE-2019-1020018   2019-07-29  2022-04-18
#
#    Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 0                            22413.0      1      79                   XSS
# 1                             3011.0      2     287               Unknown
#
#    Score  Access Complexity  ...    Conf.   Integ.    Avail cluster  \
# 0    4.3  Remote     Medium  ...      NaN  Partial      NaN       0
# 1    7.5  Remote        Low  ...  Partial  Partial  Partial       2
#
#                                          CVE Summary  \
# 0      invenio-previewer before 1.0.0a12 allows XSS.
# 1  Discourse before 2.3.0 and 2.4.x before 2.4.0....
#
#                                   Vulnerability Name  \
# 0  Failure to Preserve Web Page Structure ('Cross...
# 1                            Improper Authentication
#
#                            Vulnerability Description  \
# 0       The software does not sufficiently valida...
# 1       When an actor claims to have a given iden...
#
#                                           CLEAN TEXT cluster_2  CI SCORE
# 0  failure preserve web page structure cross site...         1  0.666677
# 1  improper authentication actor claim give ident...         2  0.625171
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Plots

# %%
ci_score = full_data_clustered_ssim['CI SCORE']

# %%
np.mean(ci_score)
# Out:
# 0.7046297998870444

# %%
ci_score.nunique()
# Out:
# 52905

# %%
round(ci_score,2).value_counts()
# Out:
# CI SCORE
# 0.67    5495
# 0.72    5354
# 0.74    5251
# 0.71    5138
# 0.73    4925
# 0.70    4788
# 0.68    4121
# 0.75    4094
# 0.66    3979
# 0.69    3941
# 0.76    3042
# 0.65    2071
# 0.77    1771
# 0.64    1484
# 0.78     984
# 0.79     937
# 0.63     838
# 0.62     572
# 0.80     503
# 0.61     460
# 0.60     449
# 0.59     366
# 0.58     286
# 0.81     232
# 0.57     179
# 0.56     145
# 0.55      87
# 0.54      60
# 0.82      52
# 0.53      22
# 0.51      12
# 0.52      12
# 0.83       8
# 0.50       8
# 0.49       6
# 0.47       4
# 0.41       3
# 0.34       3
# 0.46       3
# 0.39       2
# 0.36       1
# 0.33       1
# 0.32       1
# 0.44       1
# 0.29       1
# 0.43       1
# 0.30       1
# 0.31       1
# 0.84       1
# 0.37       1
# 0.45       1
# Name: count, dtype: int64

# %%
sel = ['CVE ID','index','Vulnerability Type(s)','CLEAN TEXT','CI SCORE']

threshold = 0.8
full_data_clustered_ssim[sel][full_data_clustered_ssim['CI SCORE'] >= 0.78 ]
# Out:
#                  CVE ID  index Vulnerability Type(s)  \
# 35     CVE-2019-1010283     36                 +Info
# 38     CVE-2019-1010266     39                   DoS
# 40     CVE-2019-1010262     41                   DoS
# 49     CVE-2019-1010249     50              Overflow
# 87     CVE-2019-1010172     88                   DoS
# ...                 ...    ...                   ...
# 61674     CVE-2014-0068  61675               Unknown
# 61675    CVE-2013-20004  61676                   DoS
# 61677    CVE-2013-10004  61678               Unknown
# 61694    CVE-2007-20001  61695                   DoS
# 61697     CVE-2003-5002  61698               Unknown
#
#                                               CLEAN TEXT  CI SCORE
# 35     information exposure information exposure inte...  0.801313
# 38     allocation resources limits throttling softwar...  0.806116
# 40     expose dangerous method function software prov...  0.790834
# 49     integer overflow wraparound software perform c...  0.784686
# 87     uncontrolle resource consumption resource exha...  0.796503
# ...                                                  ...       ...
# 61674  incorrect permission assignment critical resou...  0.793969
# 61675  uncontrolle resource consumption resource exha...  0.787583
# 61677  improper restriction excessive authentication ...  0.792994
# 61694  uncontrolle resource consumption resource exha...  0.789261
# 61697  cleartext transmission sensitive information s...  0.804882
#
# [2185 rows x 5 columns]

# %% [markdown]
# # Testing Anothers Pretrained models

# %% [markdown]
# ## Hugging face

# %%
# !pip install -U sentence-transformers
# !pip install sentence-transformers

# %%
# from sentence_transformers import SentenceTransformer, util

# s1 = full_data_clustered['CLEAN TEXT'][1]
# s2 = 'critical infrastructure'

# #Compute embedding for both lists
# embedding_1= model.encode(s1, convert_to_tensor=True)
# embedding_2 = model.encode(s2, convert_to_tensor=True)

# util.pytorch_cos_sim(embedding_1, embedding_2)
# ## tensor([[0.6003]])

# %% [markdown]
# ## Transformers
# - you can use various techniques to measure semantic similarity between a given text and a target term. Here, I'll show you how to do it using the transformers library with the pre-trained RoBERTa model. First, make sure you have the library installed:

# %%
# from sentence_transformers import SentenceTransformer, util

# model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# def similarity_trfs(text):
#     target = "critical infrastructure"
#     embedding_text = model.encode(text, convert_to_tensor=True)
#     embedding_target = model.encode(target, convert_to_tensor=True)
#     similarity = util.pytorch_cos_sim(embedding_text, embedding_target)
#     return similarity.item()

# sim_trfs = full_data_clustered.sample(50)
# sim_trfs['CI SCORE TRFS'] = sim_trfs['CLEAN TEXT'].apply(similarity_trfs)
# sim_trfs[['CVE ID','index','CLEAN TEXT','CI SCORE TRFS']]
# Out:
#                CVE ID  index  \
# 390    CVE-2019-19719    391
# 744    CVE-2019-18664    745
# 29686  CVE-2021-38604  29687
# 56967   CVE-2022-0676  56968
# 34112  CVE-2021-27330  34113
# 39895  CVE-2020-27862  39896
# 39314  CVE-2020-36370  39315
# 13911  CVE-2020-27758  13912
# 53132  CVE-2022-22274  53133
# 33334  CVE-2021-29297  33335
# 28079  CVE-2021-43804  28080
# 22780   CVE-2020-1744  22781
# 57750  CVE-2021-46162  57751
# 31644  CVE-2021-33218  31645
# 5661    CVE-2019-8576   5662
# 50555  CVE-2022-26982  50556
# 34498  CVE-2021-26236  34499
# 33246  CVE-2021-29502  33247
# 33147  CVE-2021-29608  33148
# 50694  CVE-2022-26737  50695
# 32621  CVE-2021-30791  32622
# 29667  CVE-2021-38646  29668
# 8258    CVE-2019-2193   8259
# 49039  CVE-2022-29898  49040
# 19204   CVE-2020-8827  19205
# 54884   CVE-2022-3619  54885
# 15615  CVE-2020-15927  15616
# 57638  CVE-2021-46444  57639
# 27911  CVE-2021-44444  27912
# 20537   CVE-2020-6329  20538
# 9129    CVE-2019-0729   9130
# 20920   CVE-2020-5747  20921
# 25761  CVE-2019-10612  25762
# 25185  CVE-2019-16512  25186
# 17693  CVE-2020-11467  17694
# 25395  CVE-2019-14626  25396
# 26968   CVE-2015-3154  26969
# 49329  CVE-2022-29393  49330
# 27932  CVE-2021-44350  27933
# 30033  CVE-2021-37927  30034
# 59498  CVE-2021-36867  59499
# 31189  CVE-2021-34586  31190
# 57009   CVE-2022-0622  57010
# 4730   CVE-2019-10085   4731
# 10233  CVE-2018-17679  10234
# 24714  CVE-2019-20224  24715
# 7190    CVE-2019-5805   7191
# 1215   CVE-2019-17212   1216
# 45227  CVE-2022-38497  45228
# 42242   CVE-2019-4588  42243
#
#                                               CLEAN TEXT  CI SCORE TRFS
# 390    failure preserve web page structure cross site...       0.101020
# 744    failure preserve web page structure cross site...       0.101078
# 29686  null pointer dereference null pointer derefere...       0.131254
# 56967  bound write software write datum past end begi...       0.158615
# 34112  failure preserve web page structure cross site...       0.068188
# 39895  improper sanitization special elements command...       0.238997
# 39314  bound write software write datum past end begi...       0.195810
# 13911  integer overflow wraparound software perform c...       0.092211
# 53132  bound write software write datum past end begi...       0.199048
# 33334  buffer copy check size input classic buffer ov...       0.188252
# 28079  bound read software read datum past end beginn...       0.170593
# 22780  improper handling exceptional conditions softw...       0.208630
# 57750  bound write software write datum past end begi...       0.186441
# 31644  use hard code credential software contain hard...       0.192836
# 5661   bound read software read datum past end beginn...       0.085242
# 50555  incorrect permission assignment critical resou...       0.214264
# 34498  bound write software write datum past end begi...       0.144665
# 33246  failure control generation code code injection...       0.142914
# 33147  incorrect calculation buffer size software cor...       0.169334
# 50694  bound write software write datum past end begi...       0.103462
# 32621  bound read software read datum past end beginn...       0.087485
# 29667  failure constrain operations bound memory buff...       0.165812
# 8258   improper privilege management software properl...       0.025178
# 49039  improper validation integrity check value soft...       0.124089
# 19204  improper authentication actor claim give ident...       0.047389
# 54884  failure release memory remove reference memory...       0.153746
# 15615  improper sanitization special elements sql com...       0.063996
# 57638  improper sanitization special elements sql com...       0.096428
# 27911  bound read software read datum past end beginn...       0.208986
# 20537  use free referencing memory free cause program...       0.058605
# 9129   insufficient entropy prng lack entropy availab...       0.147729
# 20920  failure preserve web page structure cross site...       0.107741
# 25761  bound write software write datum past end begi...       0.180993
# 25185  failure preserve web page structure cross site...       0.084686
# 17693  incorrect permission assignment critical resou...       0.154193
# 25395  improper privilege management software properl...       0.116547
# 26968  failure sanitize datum different plane injecti...       0.124755
# 49329  bound write software write datum past end begi...       0.132760
# 27932  improper sanitization special elements sql com...       0.093073
# 30033  improper verification cryptographic signature ...       0.047225
# 59498  failure preserve web page structure cross site...       0.103471
# 31189  null pointer dereference null pointer derefere...       0.098385
# 57009  information exposure error message software ge...       0.148402
# 4730   failure preserve web page structure cross site...       0.107152
# 10233  use free referencing memory free cause program...       0.174260
# 24714  improper sanitization special elements os comm...       0.113075
# 7190   bound write software write datum past end begi...       0.166381
# 1215   bound write software write datum past end begi...       0.121967
# 45227  uncontrolle resource consumption resource exha...       0.172177
# 42242  uncontrolle search path element product use fi...       0.010859

# %% [markdown]
# ## BERT

# %%
import transformers
import numpy as np
import torch

# Load the RoBERTa model and tokenizer
model_name = 'roberta-base'
model = transformers.RobertaModel.from_pretrained(model_name)
tokenizer = transformers.RobertaTokenizer.from_pretrained(model_name)

# Define your texts
text1 = full_data_clustered_ssim['CLEAN TEXT'][1]
text2 = "Critical infrastructure"

# Tokenize and encode the texts
inputs1 = tokenizer(text1, return_tensors='pt', padding=True, truncation=True, max_length=512)
inputs2 = tokenizer(text2, return_tensors='pt', padding=True, truncation=True, max_length=512)

# Get the contextual embeddings
with torch.no_grad():
    embeddings1 = model(**inputs1).last_hidden_state.mean(dim=1)
    embeddings2 = model(**inputs2).last_hidden_state.mean(dim=1)

# Calculate the cosine similarity
similarity = np.dot(embeddings1, embeddings2.T) / (np.linalg.norm(embeddings1) * np.linalg.norm(embeddings2))
print(similarity)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [[0.8344635]]

# %% [markdown]
# ## BERT 2

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

# Load BERT model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Define text and target term
text = full_data_clustered['CLEAN TEXT'][1]
target = "critical infrastructure"

# Tokenize and encode the text and target
inputs = tokenizer(text, target, return_tensors='pt', padding=True, truncation=True)
with torch.no_grad():
    text_output = model(**inputs)['last_hidden_state'][:, 0]  # Taking the [CLS] token embedding for text
    target_output = model(**inputs)['last_hidden_state'][:, 1]  # Taking the [CLS] token embedding for target

# Calculate cosine similarity between embeddings
similarity_score = cosine_similarity(text_output, target_output)[0][0]
print("Semantic Similarity:", similarity_score)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Semantic Similarity: 0.6475706

# %% [markdown]
# ## GloVe

# %%
import gensim.downloader as api
from sklearn.metrics.pairwise import cosine_similarity

# glove-wiki-gigaword-50 : Semantic Similarity: 0.67194796
# glove-wiki-gigaword-200 : Semantic Similarity: 0.55132633
# glove-wiki-gigaword-100 : Semantic Similarity: 0.6053121

glove_vectors2 = api.load("glove-wiki-gigaword-100")

# Define text and target term
text = "This is an example text that you want to measure similarity for."
target = "critical infrastructure"

# Tokenize and process text and target embeddings
text_words = text.lower().split()
target_words = target.lower().split()

text_embedding = np.mean([glove_vectors2[word] for word in text_words if word in glove_vectors2], axis=0)
target_embedding = np.mean([glove_vectors2[word] for word in target_words if word in glove_vectors2], axis=0)

# Calculate cosine similarity between embeddings
similarity_score = cosine_similarity([text_embedding], [target_embedding])[0][0]
print("Semantic Similarity:", similarity_score)
# Out:
# Semantic Similarity: 0.6053121

# %%
# glove_vectors3 = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %% [markdown]
# # SELECTION 1 - BERT (bert-base-uncased)

# %%
full_data_clustered['CLEAN TEXT'][1]

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
target = "critical infrastructure"


def similarity_bert(text):
    
    # Tokenize and encode the text and target
    inputs = tokenizer(text, target, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        text_output = model(**inputs)['last_hidden_state'][:, 0]  # Taking the [CLS] token embedding for text
        target_output = model(**inputs)['last_hidden_state'][:, 1]  # Taking the [CLS] token embedding for target
    
    similarity_score = cosine_similarity(text_output, target_output)[0][0]
    return similarity_score



similarity_bert(full_data_clustered['CLEAN TEXT'][1])
sim_bert = full_data_clustered.sample(5)
sim_bert['CI SCORE BERT'] = sim_bert['CLEAN TEXT'].apply(similarity_bert)
sim_bert[['CVE ID','index','CLEAN TEXT','CI SCORE BERT']]
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#                CVE ID  index  \
# 23713   CVE-2020-0667  23714
# 48664  CVE-2022-30668  48665
# 27803  CVE-2021-45261  27804
# 10807  CVE-2018-13104  10808
# 43806  CVE-2022-42206  43807
#
#                                               CLEAN TEXT  CI SCORE BERT
# 23713  improper privilege management software properl...       0.576609
# 48664  bound read software read datum past end beginn...       0.067523
# 27803  release invalid pointer reference application ...       0.373779
# 10807  failure preserve web page structure cross site...       0.287724
# 43806  failure preserve web page structure cross site...       0.326014

# %%
def chunks_scores(csv_input_name, input_column, output_column, csv_output_name, func, chunksize=10000):
    i = 1
    df = pd.DataFrame()
    for reader in pd.read_csv(csv_input_name, usecols=['index','CLEAN TEXT','CI SCORE'], chunksize=chunksize):
        reader[output_column] = reader[input_column].apply(func)
        print('chunk',i,'\n ',reader,'\n=============================\n')
        df = pd.concat([df,reader] , ignore_index=True)
        i = i+1
    return df.to_csv(csv_output_name , index=False)


# chunks_scores(
#     csv_input_name = 'full_data_clustered_ssim.csv',
#     input_column = 'CLEAN TEXT',
#     output_column = 'CI SCORE BERT',
#     csv_output_name = 'full_data_clustered_ssim_V2.csv',
#     func = similarity_bert,
#     chunksize = 1000
# )
# Out:
# chunk 1
#        index                                         CLEAN TEXT  CI SCORE  \
# 0        1  failure preserve web page structure cross site...  0.666677
# 1        2  improper authentication actor claim give ident...  0.625171
# 2        3  url redirection untrusted site open redirect w...  0.636100
# 3        4  improper input validation product validate inc...  0.719175
# 4        5  double free product call free twice memory add...  0.707726
# ..     ...                                                ...       ...
# 995    996  access control bypass user control key system ...  0.723874
# 996    997  deserialization untrusted data application des...  0.735792
# 997    998  failure sanitize datum different plane injecti...  0.742766
# 998    999  deserialization untrusted data application des...  0.708179
# 999   1000  improper input validation product validate inc...  0.720398
#
#      CI SCORE BERT
# 0         0.468787
# 1         0.647571
# 2         0.061754
# 3         0.379388
# 4         0.583270
# ..             ...
# 995       0.275867
# 996       0.216696
# 997       0.234382
# 998       0.075706
# 999       0.291836
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 2
#         index                                         CLEAN TEXT  CI SCORE  \
# 1000   1001  information leak xml external entity file disc...  0.681346
# 1001   1002  improper sanitization special elements sql com...  0.712258
# 1002   1003  improper sanitization special elements sql com...  0.720496
# 1003   1004  failure preserve web page structure cross site...  0.687515
# 1004   1005  failure preserve web page structure cross site...  0.660880
# ...     ...                                                ...       ...
# 1995   1996  improper limitation pathname restricted direct...  0.745268
# 1996   1997  information exposure information exposure inte...  0.707144
# 1997   1998  insufficient lock software properly acquire lo...  0.754070
# 1998   1999  improper privilege management software properl...  0.737339
# 1999   2000  information leak log files information write l...  0.654972
#
#       CI SCORE BERT
# 1000       0.295742
# 1001       0.322076
# 1002       0.300033
# 1003       0.294561
# 1004       0.309087
# ...             ...
# 1995       0.231600
# 1996       0.508236
# 1997       0.248463
# 1998       0.263852
# 1999       0.407469
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 3
#         index                                         CLEAN TEXT  CI SCORE  \
# 2000   2001  information leak log files information write l...  0.665285
# 2001   2002  information exposure information exposure inte...  0.759937
# 2002   2003  bound read software read datum past end beginn...  0.677041
# 2003   2004  double free product call free twice memory add...  0.699770
# 2004   2005  improper sanitization special elements os comm...  0.756744
# ...     ...                                                ...       ...
# 2995   2996  bound read software read datum past end beginn...  0.693280
# 2996   2997  bound read software read datum past end beginn...  0.676009
# 2997   2998  bound read software read datum past end beginn...  0.691242
# 2998   2999  bound write software write datum past end begi...  0.693410
# 2999   3000  bound write software write datum past end begi...  0.708962
#
#       CI SCORE BERT
# 2000       0.447121
# 2001       0.317854
# 2002       0.163542
# 2003       0.574949
# 2004       0.149951
# ...             ...
# 2995       0.133426
# 2996       0.167545
# 2997       0.154955
# 2998       0.188711
# 2999       0.135543
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 4
#         index                                         CLEAN TEXT  CI SCORE  \
# 3000   3001  bound write software write datum past end begi...  0.719105
# 3001   3002  improper sanitization special elements os comm...  0.756262
# 3002   3003  bound write software write datum past end begi...  0.714295
# 3003   3004  improper sanitization special elements sql com...  0.704196
# 3004   3005  failure preserve web page structure cross site...  0.672940
# ...     ...                                                ...       ...
# 3995   3996  weak password recovery mechanism forgotten pas...  0.664676
# 3996   3997  information leak xml external entity file disc...  0.680376
# 3997   3998  uncontrolle resource consumption resource exha...  0.790692
# 3998   3999  uncontrolle resource consumption resource exha...  0.790692
# 3999   4000  uncontrolle resource consumption resource exha...  0.790692
#
#       CI SCORE BERT
# 3000       0.132087
# 3001       0.139141
# 3002       0.152045
# 3003       0.304275
# 3004       0.334206
# ...             ...
# 3995       0.230168
# 3996       0.325928
# 3997       0.167601
# 3998       0.167601
# 3999       0.167601
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 5
#         index                                         CLEAN TEXT  CI SCORE  \
# 4000   4001  uncontrolle resource consumption resource exha...  0.789558
# 4001   4002  uncontrolle resource consumption resource exha...  0.789259
# 4002   4003  cleartext storage sensitive information applic...  0.687415
# 4003   4004  unrestricted upload file dangerous type softwa...  0.607048
# 4004   4005  unrestricted upload file dangerous type softwa...  0.635333
# ...     ...                                                ...       ...
# 4995   4996  miss encryption sensitive data software encryp...  0.767792
# 4996   4997  information exposure information exposure inte...  0.749749
# 4997   4998  incorrect default permissions software install...  0.704613
# 4998   4999  improper input validation product validate inc...  0.743114
# 4999   5000  buffer copy check size input classic buffer ov...  0.672338
#
#       CI SCORE BERT
# 4000       0.161078
# 4001       0.171617
# 4002       0.122714
# 4003       0.150011
# 4004       0.548286
# ...             ...
# 4995       0.488580
# 4996       0.399251
# 4997       0.360809
# 4998       0.323513
# 4999       0.174366
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 6
#         index                                         CLEAN TEXT  CI SCORE  \
# 5000   5001  failure constrain operations bound memory buff...  0.758348
# 5001   5002  failure constrain operations bound memory buff...  0.759784
# 5002   5003  information leak xml external entity file disc...  0.698515
# 5003   5004  failure preserve web page structure cross site...  0.678055
# 5004   5005  improper input validation product validate inc...  0.737177
# ...     ...                                                ...       ...
# 5995   5996  use free referencing memory free cause program...  0.685423
# 5996   5997  use free referencing memory free cause program...  0.685423
# 5997   5998  use free referencing memory free cause program...  0.685423
# 5998   5999  bound read software read datum past end beginn...  0.722295
# 5999   6000  use free referencing memory free cause program...  0.685423
#
#       CI SCORE BERT
# 5000       0.255428
# 5001       0.296511
# 5002       0.308455
# 5003       0.268342
# 5004       0.271389
# ...             ...
# 5995       0.394869
# 5996       0.394869
# 5997       0.394869
# 5998       0.083023
# 5999       0.394869
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 7
#         index                                         CLEAN TEXT  CI SCORE  \
# 6000   6001  bound write software write datum past end begi...  0.728139
# 6001   6002  bound write software write datum past end begi...  0.728139
# 6002   6003  failure constrain operations bound memory buff...  0.769303
# 6003   6004  use free referencing memory free cause program...  0.685423
# 6004   6005  bound write software write datum past end begi...  0.728139
# ...     ...                                                ...       ...
# 6995   6996  bound write software write datum past end begi...  0.712561
# 6996   6997  bound write software write datum past end begi...  0.715836
# 6997   6998  bound write software write datum past end begi...  0.732426
# 6998   6999  failure constrain operations bound memory buff...  0.752135
# 6999   7000  bound read software read datum past end beginn...  0.684852
#
#       CI SCORE BERT
# 6000       0.147384
# 6001       0.147384
# 6002       0.321726
# 6003       0.394869
# 6004       0.147384
# ...             ...
# 6995       0.190538
# 6996       0.179568
# 6997       0.139813
# 6998       0.307522
# 6999       0.099811
#
# [1000 rows x 4 columns]
# =============================
# chunk 8
#         index                                         CLEAN TEXT  CI SCORE  \
# 7000   7001  bound read software read datum past end beginn...  0.698663
# 7001   7002  improper input validation product validate inc...  0.750934
# 7002   7003  bound write software write datum past end begi...  0.715184
# 7003   7004  bound write software write datum past end begi...  0.715836
# 7004   7005  bound write software write datum past end begi...  0.715836
# ...     ...                                                ...       ...
# 7995   7996  information exposure discrepancy product behav...  0.806276
# 7996   7997  miss required cryptographic step software impl...  0.732232
# 7997   7998  improper limitation pathname restricted direct...  0.736240
# 7998   7999  use broken risky cryptographic algorithm use b...  0.732156
# 7999   8000  improper privilege management software properl...  0.735039
#
#       CI SCORE BERT
# 7000       0.102631
# 7001       0.391553
# 7002       0.129993
# 7003       0.179568
# 7004       0.179568
# ...             ...
# 7995       0.336069
# 7996       0.277020
# 7997       0.209773
# 7998       0.214424
# 7999       0.449749
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 9
#         index                                         CLEAN TEXT  CI SCORE  \
# 8000   8001  incomplete cleanup software properly clean rem...  0.757277
# 8001   8002  information exposure discrepancy product behav...  0.765697
# 8002   8003  information exposure discrepancy product behav...  0.775500
# 8003   8004  information exposure error message software ge...  0.719824
# 8004   8005  bound write software write datum past end begi...  0.748557
# ...     ...                                                ...       ...
# 8995   8996  information exposure information exposure inte...  0.706165
# 8996   8997  information exposure information exposure inte...  0.706165
# 8997   8998  improper initialization software initialize in...  0.762033
# 8998   8999  bound write software write datum past end begi...  0.710148
# 8999   9000  failure preserve web page structure cross site...  0.666286
#
#       CI SCORE BERT
# 8000       0.337702
# 8001       0.319109
# 8002       0.347998
# 8003       0.276507
# 8004       0.155430
# ...             ...
# 8995       0.514701
# 8996       0.514701
# 8997       0.185449
# 8998       0.153186
# 8999       0.339929
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 10
#         index                                         CLEAN TEXT  CI SCORE  \
# 9000   9001  failure preserve web page structure cross site...  0.666286
# 9001   9002  failure preserve web page structure cross site...  0.666286
# 9002   9003  failure preserve web page structure cross site...  0.666286
# 9003   9004  information exposure information exposure inte...  0.741975
# 9004   9005  bound write software write datum past end begi...  0.691489
# ...     ...                                                ...       ...
# 9995   9996  improper limitation pathname restricted direct...  0.740068
# 9996   9997  deserialization untrusted data application des...  0.760590
# 9997   9998  deserialization untrusted data application des...  0.751850
# 9998   9999  deserialization untrusted data application des...  0.757494
# 9999  10000  improper input validation product validate inc...  0.684001
#
#       CI SCORE BERT
# 9000       0.339929
# 9001       0.339929
# 9002       0.339929
# 9003       0.500787
# 9004       0.152551
# ...             ...
# 9995       0.214183
# 9996       0.142029
# 9997       0.082500
# 9998       0.095360
# 9999       0.398347
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 11
#          index                                         CLEAN TEXT  CI SCORE  \
# 10000  10001  uncontrolle resource consumption resource exha...  0.797584
# 10001  10002  deserialization untrusted data application des...  0.736738
# 10002  10003  improper authentication actor claim give ident...  0.670637
# 10003  10004  failure preserve web page structure cross site...  0.673625
# 10004  10005  failure preserve web page structure cross site...  0.670681
# ...      ...                                                ...       ...
# 10995  10996  information exposure information exposure inte...  0.686931
# 10996  10997  failure preserve web page structure cross site...  0.681798
# 10997  10998  failure preserve web page structure cross site...  0.674208
# 10998  10999  information exposure information exposure inte...  0.730579
# 10999  11000  failure preserve web page structure cross site...  0.665230
#
#        CI SCORE BERT
# 10000       0.163075
# 10001       0.105793
# 10002       0.591818
# 10003       0.361526
# 10004       0.378173
# ...              ...
# 10995       0.450092
# 10996       0.303124
# 10997       0.262764
# 10998       0.417363
# 10999       0.313747
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 12
#          index                                         CLEAN TEXT  CI SCORE  \
# 11000  11001  failure constrain operations bound memory buff...  0.741834
# 11001  11002  improper sanitization special elements os comm...  0.753638
# 11002  11003  failure constrain operations bound memory buff...  0.741834
# 11003  11004  failure preserve web page structure cross site...  0.688882
# 11004  11005  improper sanitization special elements os comm...  0.748024
# ...      ...                                                ...       ...
# 11995  11996  failure constrain operations bound memory buff...  0.748351
# 11996  11997  improper input validation product validate inc...  0.728595
# 11997  11998  failure preserve web page structure cross site...  0.663199
# 11998  11999  improper sanitization special elements sql com...  0.725368
# 11999  12000  information exposure information exposure inte...  0.705527
#
#        CI SCORE BERT
# 11000       0.322736
# 11001       0.159478
# 11002       0.322736
# 11003       0.323699
# 11004       0.162577
# ...              ...
# 11995       0.312478
# 11996       0.298996
# 11997       0.301699
# 11998       0.309166
# 11999       0.317676
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 13
#          index                                         CLEAN TEXT  CI SCORE  \
# 12000  12001  unrestricted upload file dangerous type softwa...  0.572020
# 12001  12002  failure preserve web page structure cross site...  0.634719
# 12002  12003  improper sanitization special elements sql com...  0.710111
# 12003  12004  information exposure information exposure inte...  0.730520
# 12004  12005  improper authentication actor claim give ident...  0.697619
# ...      ...                                                ...       ...
# 12995  12996  improper privilege management software properl...  0.728617
# 12996  12997  improper input validation product validate inc...  0.724883
# 12997  12998  incorrect default permissions software install...  0.673199
# 12998  12999  incorrect default permissions software install...  0.642545
# 12999  13000  cleartext transmission sensitive information s...  0.787795
#
#        CI SCORE BERT
# 12000       0.159712
# 12001       0.307439
# 12002       0.233986
# 12003       0.456436
# 12004       0.511432
# ...              ...
# 12995       0.544838
# 12996       0.399488
# 12997       0.399661
# 12998       0.406849
# 12999       0.054833
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 14
#          index                                         CLEAN TEXT  CI SCORE  \
# 13000  13001  information exposure information exposure inte...  0.730873
# 13001  13002  insufficiently protected credential weakness o...  0.704689
# 13002  13003  reachable assertion product contain assert sim...  0.726594
# 13003  13004  information exposure information exposure inte...  0.704568
# 13004  13005  miss encryption sensitive data software encryp...  0.737127
# ...      ...                                                ...       ...
# 13995  13996  buffer copy check size input classic buffer ov...  0.684932
# 13996  13997  improper validation array index product use un...  0.737977
# 13997  13998  integer overflow wraparound software perform c...  0.770307
# 13998  13999  improper validation array index product use un...  0.712013
# 13999  14000  improper sanitization special elements sql com...  0.694893
#
#        CI SCORE BERT
# 13000       0.529472
# 13001       0.489335
# 13002       0.275833
# 13003       0.462340
# 13004       0.410429
# ...              ...
# 13995       0.200468
# 13996       0.520792
# 13997       0.079610
# 13998       0.550844
# 13999       0.237684
#
# [1000 rows x 4 columns]
# =============================
# chunk 15
#          index                                         CLEAN TEXT  CI SCORE  \
# 14000  14001  failure preserve web page structure cross site...  0.652731
# 14001  14002  improper restriction excessive authentication ...  0.716871
# 14002  14003  insufficient session expiration accord wasc in...  0.579040
# 14003  14004  failure preserve web page structure cross site...  0.682268
# 14004  14005  inadequate encryption strength software store ...  0.762081
# ...      ...                                                ...       ...
# 14995  14996  bound write software write datum past end begi...  0.731030
# 14996  14997  improper sanitization special elements os comm...  0.757871
# 14997  14998  improper limitation pathname restricted direct...  0.754012
# 14998  14999  unrestricted recursive entity references dtd x...  0.692493
# 14999  15000  improper authentication actor claim give ident...  0.758497
#
#        CI SCORE BERT
# 14000       0.330424
# 14001       0.296296
# 14002       0.244898
# 14003       0.343171
# 14004       0.317557
# ...              ...
# 14995       0.237658
# 14996       0.189448
# 14997       0.171584
# 14998       0.137571
# 14999       0.571960
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 16
#          index                                         CLEAN TEXT  CI SCORE  \
# 15000  15001  improper privilege management software properl...  0.657086
# 15001  15002  improper privilege management software properl...  0.651045
# 15002  15003  deserialization untrusted data application des...  0.703881
# 15003  15004  improper sanitization special elements os comm...  0.756502
# 15004  15005  operation resource expiration release software...  0.726761
# ...      ...                                                ...       ...
# 15995  15996  argument injection modification software suffi...  0.729806
# 15996  15997  information exposure discrepancy product behav...  0.727000
# 15997  15998  improper limitation pathname restricted direct...  0.737382
# 15998  15999  information exposure information exposure inte...  0.741257
# 15999  16000  failure resolve case sensitivity software prop...  0.715212
#
#        CI SCORE BERT
# 15000       0.228407
# 15001       0.287294
# 15002       0.100635
# 15003       0.163032
# 15004       0.226911
# ...              ...
# 15995       0.121194
# 15996       0.331581
# 15997       0.192556
# 15998       0.459443
# 15999       0.505524
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 17
#          index                                         CLEAN TEXT  CI SCORE  \
# 16000  16001  url redirection untrusted site open redirect w...  0.635641
# 16001  16002  information leak xml external entity file disc...  0.680743
# 16002  16003  failure preserve web page structure cross site...  0.664530
# 16003  16004  improper limitation pathname restricted direct...  0.742098
# 16004  16005  improper limitation pathname restricted direct...  0.723917
# ...      ...                                                ...       ...
# 16995  16996  integer overflow wraparound software perform c...  0.749095
# 16996  16997  deserialization untrusted data application des...  0.737171
# 16997  16998  failure preserve web page structure cross site...  0.665125
# 16998  16999  improper resource shutdown release program rel...  0.749105
# 16999  17000  improper privilege management software properl...  0.713788
#
#        CI SCORE BERT
# 16000       0.106209
# 16001       0.359977
# 16002       0.291795
# 16003       0.207394
# 16004       0.176430
# ...              ...
# 16995       0.060138
# 16996       0.097362
# 16997       0.326402
# 16998       0.475077
# 16999       0.569448
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 18
#          index                                         CLEAN TEXT  CI SCORE  \
# 17000  17001  information exposure information exposure inte...  0.715787
# 17001  17002  bound write software write datum past end begi...  0.678461
# 17002  17003  insufficiently protected credential weakness o...  0.673978
# 17003  17004  failure constrain operations bound memory buff...  0.707570
# 17004  17005  buffer copy check size input classic buffer ov...  0.623991
# ...      ...                                                ...       ...
# 17995  17996  bound write software write datum past end begi...  0.695888
# 17996  17997  failure preserve web page structure cross site...  0.666686
# 17997  17998  failure preserve web page structure cross site...  0.672748
# 17998  17999  failure preserve web page structure cross site...  0.672058
# 17999  18000  improper sanitization special elements os comm...  0.754974
#
#        CI SCORE BERT
# 17000       0.524729
# 17001       0.206832
# 17002       0.364840
# 17003       0.332336
# 17004       0.180097
# ...              ...
# 17995       0.157477
# 17996       0.385120
# 17997       0.393773
# 17998       0.385302
# 17999       0.192661
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 19
#          index                                         CLEAN TEXT  CI SCORE  \
# 18000  18001  improper sanitization special elements sql com...  0.715525
# 18001  18002  improper authentication actor claim give ident...  0.685473
# 18002  18003  buffer copy check size input classic buffer ov...  0.643482
# 18003  18004  buffer copy check size input classic buffer ov...  0.641460
# 18004  18005  null pointer dereference null pointer derefere...  0.641249
# ...      ...                                                ...       ...
# 18995  18996  improper privilege management software properl...  0.753727
# 18996  18997  information exposure information exposure inte...  0.753308
# 18997  18998  improper authentication actor claim give ident...  0.690724
# 18998  18999  bound read software read datum past end beginn...  0.696414
# 18999  19000  failure control generation code code injection...  0.689272
#
#        CI SCORE BERT
# 18000       0.362056
# 18001       0.599110
# 18002       0.211941
# 18003       0.187186
# 18004       0.133742
# ...              ...
# 18995       0.406587
# 18996       0.458596
# 18997       0.543961
# 18998       0.199787
# 18999       0.253849
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 20
#          index                                         CLEAN TEXT  CI SCORE  \
# 19000  19001  improper input validation product validate inc...  0.765445
# 19001  19002  failure constrain operations bound memory buff...  0.783837
# 19002  19003  inadequate encryption strength software store ...  0.770715
# 19003  19004  improper sanitization special elements command...  0.744555
# 19004  19005  bound read software read datum past end beginn...  0.712017
# ...      ...                                                ...       ...
# 19995  19996  authentication bypass spoof attack focus weakn...  0.757003
# 19996  19997  authentication bypass spoof attack focus weakn...  0.760905
# 19997  19998  improper link resolution file access link foll...  0.632459
# 19998  19999  improper privilege management software properl...  0.733142
# 19999  20000  improper authentication actor claim give ident...  0.705449
#
#        CI SCORE BERT
# 19000       0.217104
# 19001       0.277793
# 19002       0.283014
# 19003       0.501929
# 19004       0.134976
# ...              ...
# 19995       0.366942
# 19996       0.312232
# 19997       0.240435
# 19998       0.454077
# 19999       0.612316
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 21
#          index                                         CLEAN TEXT  CI SCORE  \
# 20000  20001  information leak log files information write l...  0.694883
# 20001  20002  improper link resolution file access link foll...  0.643591
# 20002  20003  failure preserve web page structure cross site...  0.667198
# 20003  20004  failure preserve web page structure cross site...  0.663128
# 20004  20005  unquoted search path element product use searc...  0.707472
# ...      ...                                                ...       ...
# 20995  20996  improper authentication actor claim give ident...  0.703639
# 20996  20997  url redirection untrusted site open redirect w...  0.645466
# 20997  20998  failure preserve web page structure cross site...  0.672029
# 20998  20999  improper limitation pathname restricted direct...  0.753910
# 20999  21000  failure sanitize datum different plane injecti...  0.735528
#
#        CI SCORE BERT
# 20000       0.400463
# 20001       0.208611
# 20002       0.319892
# 20003       0.337417
# 20004       0.099265
# ...              ...
# 20995       0.581863
# 20996       0.075608
# 20997       0.341361
# 20998       0.230529
# 20999       0.242855
#
# [1000 rows x 4 columns]
# =============================
# chunk 22
#          index                                         CLEAN TEXT  CI SCORE  \
# 21000  21001  uncontrolle resource consumption resource exha...  0.771510
# 21001  21002  information leak xml external entity file disc...  0.712156
# 21002  21003  failure sanitize datum different plane injecti...  0.748866
# 21003  21004  uncontrolle resource consumption resource exha...  0.797565
# 21004  21005  failure sanitize datum different plane injecti...  0.760305
# ...      ...                                                ...       ...
# 21995  21996  failure preserve web page structure cross site...  0.687170
# 21996  21997  improper input validation product validate inc...  0.741394
# 21997  21998  improper initialization software initialize in...  0.739513
# 21998  21999  failure release memory remove reference memory...  0.768634
# 21999  22000  improper input validation product validate inc...  0.745803
#
#        CI SCORE BERT
# 21000       0.097283
# 21001       0.244567
# 21002       0.234839
# 21003       0.180475
# 21004       0.249167
# ...              ...
# 21995       0.270038
# 21996       0.183232
# 21997       0.165601
# 21998       0.241793
# 21999       0.121756
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 23
#          index                                         CLEAN TEXT  CI SCORE  \
# 22000  22001  allocation resources limits throttling softwar...  0.797068
# 22001  22002  improper input validation product validate inc...  0.724380
# 22002  22003  improper input validation product validate inc...  0.770763
# 22003  22004  allocation resources limits throttling softwar...  0.805374
# 22004  22005  improper authentication actor claim give ident...  0.746061
# ...      ...                                                ...       ...
# 22995  22996  improper privilege management software properl...  0.750639
# 22996  22997  information exposure information exposure inte...  0.768583
# 22997  22998  bound write software write datum past end begi...  0.676335
# 22998  22999  failure preserve web page structure cross site...  0.666286
# 22999  23000  improper input validation product validate inc...  0.750103
#
#        CI SCORE BERT
# 22000       0.237049
# 22001       0.176555
# 22002       0.179818
# 22003       0.221847
# 22004       0.484971
# ...              ...
# 22995       0.469049
# 22996       0.408779
# 22997       0.205789
# 22998       0.339929
# 22999       0.257400
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 24
#          index                                         CLEAN TEXT  CI SCORE  \
# 23000  23001  failure preserve web page structure cross site...  0.698103
# 23001  23002  download code integrity check product download...  0.612805
# 23002  23003  download code integrity check product download...  0.612805
# 23003  23004  failure preserve web page structure cross site...  0.666286
# 23004  23005  failure preserve web page structure cross site...  0.666286
# ...      ...                                                ...       ...
# 23995  23996  race condition code require certain state modi...  0.769364
# 23996  23997  incorrect default permissions software install...  0.691229
# 23997  23998  use free referencing memory free cause program...  0.667422
# 23998  23999  incorrect default permissions software install...  0.691229
# 23999  24000  improper input validation product validate inc...  0.740159
#
#        CI SCORE BERT
# 23000       0.288003
# 23001       0.491815
# 23002       0.491815
# 23003       0.339929
# 23004       0.339929
# ...              ...
# 23995       0.182469
# 23996       0.353588
# 23997       0.308292
# 23998       0.353588
# 23999       0.153336
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 25
#          index                                         CLEAN TEXT  CI SCORE  \
# 24000  24001  bound read software read datum past end beginn...  0.706154
# 24001  24002  incorrect default permissions software install...  0.691957
# 24002  24003  incorrect default permissions software install...  0.675591
# 24003  24004  incorrect default permissions software install...  0.689261
# 24004  24005  incorrect default permissions software install...  0.686407
# ...      ...                                                ...       ...
# 24995  24996  improper sanitization special elements sql com...  0.700262
# 24996  24997  weak password requirements product require use...  0.684166
# 24997  24998  miss authentication critical function software...  0.732144
# 24998  24999  information exposure information exposure inte...  0.751302
# 24999  25000  miss encryption sensitive data software encryp...  0.754230
#
#        CI SCORE BERT
# 24000       0.122947
# 24001       0.375374
# 24002       0.398077
# 24003       0.382227
# 24004       0.347495
# ...              ...
# 24995       0.325119
# 24996       0.181149
# 24997       0.416667
# 24998       0.359065
# 24999       0.465983
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 26
#          index                                         CLEAN TEXT  CI SCORE  \
# 25000  25001  failure control generation code code injection...  0.673111
# 25001  25002  improper limitation pathname restricted direct...  0.748138
# 25002  25003  incorrect permission assignment critical resou...  0.813202
# 25003  25004  incorrect permission assignment critical resou...  0.813202
# 25004  25005  improper sanitization special elements os comm...  0.758118
# ...      ...                                                ...       ...
# 25995  25996  double free product call free twice memory add...  0.697911
# 25996  25997  bound write software write datum past end begi...  0.702498
# 25997  25998  bound write software write datum past end begi...  0.697783
# 25998  25999  bound write software write datum past end begi...  0.698544
# 25999  26000  bound write software write datum past end begi...  0.688704
#
#        CI SCORE BERT
# 25000       0.298731
# 25001       0.215359
# 25002       0.313033
# 25003       0.313033
# 25004       0.185512
# ...              ...
# 25995       0.534502
# 25996       0.169126
# 25997       0.155015
# 25998       0.162104
# 25999       0.181452
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 27
#          index                                         CLEAN TEXT  CI SCORE  \
# 26000  26001  bound write software write datum past end begi...  0.691597
# 26001  26002  bound write software write datum past end begi...  0.715275
# 26002  26003  bound write software write datum past end begi...  0.706111
# 26003  26004  improper sanitization special elements os comm...  0.729715
# 26004  26005  improper sanitization special elements os comm...  0.733950
# ...      ...                                                ...       ...
# 26995  26996  miss encryption sensitive data software encryp...  0.771772
# 26996  26997  unrestricted upload file dangerous type softwa...  0.605750
# 26997  26998  improper sanitization special elements sql com...  0.704846
# 26998  26999  buffer copy check size input classic buffer ov...  0.656242
# 26999  27000  bound write software write datum past end begi...  0.714274
#
#        CI SCORE BERT
# 26000       0.156462
# 26001       0.155245
# 26002       0.156938
# 26003       0.259320
# 26004       0.263091
# ...              ...
# 26995       0.495839
# 26996       0.487085
# 26997       0.309323
# 26998       0.212747
# 26999       0.195331
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 28
#          index                                         CLEAN TEXT  CI SCORE  \
# 27000  27001  buffer copy check size input classic buffer ov...  0.652856
# 27001  27002  improper authentication actor claim give ident...  0.643831
# 27002  27003  incorrect permission assignment critical resou...  0.774589
# 27003  27004  incorrect permission assignment critical resou...  0.782816
# 27004  27005  failure preserve web page structure cross site...  0.677987
# ...      ...                                                ...       ...
# 27995  27996  weak password recovery mechanism forgotten pas...  0.674070
# 27996  27997  improper restriction excessive authentication ...  0.721474
# 27997  27998  unrestricted upload file dangerous type softwa...  0.649977
# 27998  27999  failure preserve web page structure cross site...  0.669114
# 27999  28000  deserialization untrusted data application des...  0.753331
#
#        CI SCORE BERT
# 27000       0.174958
# 27001       0.592555
# 27002       0.268351
# 27003       0.290520
# 27004       0.323857
# ...              ...
# 27995       0.239038
# 27996       0.257346
# 27997       0.220487
# 27998       0.326772
# 27999       0.086415
#
# [1000 rows x 4 columns]
# =============================
# chunk 29
#          index                                         CLEAN TEXT  CI SCORE  \
# 28000  28001  information leak xml external entity file disc...  0.689251
# 28001  28002  improper sanitization special elements sql com...  0.716599
# 28002  28003  failure preserve web page structure cross site...  0.671879
# 28003  28004  improper link resolution file access link foll...  0.694005
# 28004  28005  reachable assertion product contain assert sim...  0.762124
# ...      ...                                                ...       ...
# 28995  28996  null pointer dereference null pointer derefere...  0.657720
# 28996  28997  use broken risky cryptographic algorithm use b...  0.688083
# 28997  28998  use broken risky cryptographic algorithm use b...  0.686901
# 28998  28999  buffer copy check size input classic buffer ov...  0.655662
# 28999  29000  improper sanitization special elements sql com...  0.711058
#
#        CI SCORE BERT
# 28000       0.309614
# 28001       0.329102
# 28002       0.340062
# 28003       0.231285
# 28004       0.157382
# ...              ...
# 28995       0.180420
# 28996       0.187525
# 28997       0.195664
# 28998       0.208686
# 28999       0.340874
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 30
#          index                                         CLEAN TEXT  CI SCORE  \
# 29000  29001  bound read software read datum past end beginn...  0.692980
# 29001  29002  missing release resource effective lifetime so...  0.751201
# 29002  29003  access memory location end buffer software rea...  0.719183
# 29003  29004  access memory location end buffer software rea...  0.719183
# 29004  29005  failure constrain operations bound memory buff...  0.752744
# ...      ...                                                ...       ...
# 29995  29996  use free referencing memory free cause program...  0.609964
# 29996  29997  bound read software read datum past end beginn...  0.682759
# 29997  29998  race condition code require certain state modi...  0.762531
# 29998  29999  use free referencing memory free cause program...  0.617177
# 29999  30000  use free referencing memory free cause program...  0.613323
#
#        CI SCORE BERT
# 29000       0.161092
# 29001       0.256758
# 29002       0.378764
# 29003       0.378764
# 29004       0.281870
# ...              ...
# 29995       0.250770
# 29996       0.108961
# 29997       0.299338
# 29998       0.238056
# 29999       0.293786
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 31
#          index                                         CLEAN TEXT  CI SCORE  \
# 30000  30001  bound write software write datum past end begi...  0.704163
# 30001  30002  use free referencing memory free cause program...  0.607218
# 30002  30003  bound write software write datum past end begi...  0.694164
# 30003  30004  use free referencing memory free cause program...  0.602718
# 30004  30005  use free referencing memory free cause program...  0.601468
# ...      ...                                                ...       ...
# 30995  30996  improper sanitization special elements os comm...  0.761725
# 30996  30997  improper sanitization special elements os comm...  0.756105
# 30997  30998  failure preserve web page structure cross site...  0.673450
# 30998  30999  improper authentication actor claim give ident...  0.716246
# 30999  31000  improper sanitization special elements os comm...  0.758867
#
#        CI SCORE BERT
# 30000       0.155115
# 30001       0.252218
# 30002       0.148580
# 30003       0.276945
# 30004       0.229014
# ...              ...
# 30995       0.183877
# 30996       0.140810
# 30997       0.309107
# 30998       0.569300
# 30999       0.200932
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 32
#          index                                         CLEAN TEXT  CI SCORE  \
# 31000  31001  improper limitation pathname restricted direct...  0.747815
# 31001  31002  deserialization untrusted data application des...  0.756052
# 31002  31003  bound write software write datum past end begi...  0.711430
# 31003  31004  stack base buffer overflow stack base buffer o...  0.733455
# 31004  31005  stack base buffer overflow stack base buffer o...  0.733060
# ...      ...                                                ...       ...
# 31995  31996  improper link resolution file access link foll...  0.643951
# 31996  31997  improper link resolution file access link foll...  0.643951
# 31997  31998  improper limitation pathname restricted direct...  0.734020
# 31998  31999  improper limitation pathname restricted direct...  0.734020
# 31999  32000  failure sanitize datum different plane injecti...  0.745111
#
#        CI SCORE BERT
# 31000       0.198800
# 31001       0.086104
# 31002       0.167631
# 31003       0.103852
# 31004       0.104574
# ...              ...
# 31995       0.247917
# 31996       0.239587
# 31997       0.202369
# 31998       0.201610
# 31999       0.245551
#
# [1000 rows x 4 columns]
# =============================
#
# chunk 33
#          index                                         CLEAN TEXT  CI SCORE  \
# 32000  32001  improper limitation pathname restricted direct...  0.734505
# 32001  32002  inadequate encryption strength software store ...  0.758136
# 32002  32003  bound write software write datum past end begi...  0.702006
# 32003  32004  bound read software read datum past end beginn...  0.690549
# 32004  32005  integer overflow wraparound software perform c...  0.762711
# ...      ...                                                ...       ...
# 32995  32996  race condition code require certain state modi...  0.759949
# 32996  32997  improper privilege management software properl...  0.744493
# 32997  32998  cleartext storage sensitive information applic...  0.776146
# 32998  32999  uncontrolle search path element product use fi...  0.691554
# 32999  33000  race condition code require certain state modi...  0.759856
#
#        CI SCORE BERT
# 32000       0.210498
# 32001       0.175354
# 32002       0.158924
# 32003       0.095062
# 32004       0.060390
# ...              ...
# 32995       0.206793
# 32996       0.253691
# 32997       0.097573
# 32998       0.136508
# 32999       0.230793
#
# [1000 rows x 4 columns]
# =============================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 12
#       8         i = i+1
#       9     return df.to_csv(csv_output_name , index=False)
# ---> 12 chunks_scores(
#      13     csv_input_name = 'full_data_clustered_ssim.csv',
#      14     input_column = 'CLEAN TEXT',
#      15     output_column = 'CI SCORE BERT',
#      16     csv_output_name = 'full_data_clustered_ssim_V2.csv',
#      17     func = similarity_bert,
#      18     chunksize = 1000
#      19 )
#
# Cell In[30], line 5, in chunks_scores(csv_input_name, input_column, output_column, csv_output_name, func, chunksize)
#       3 df = pd.DataFrame()
#       4 for reader in pd.read_csv(csv_input_name, usecols=['index','CLEAN TEXT','CI SCORE'], chunksize=chunksize):
# ----> 5     reader[output_column] = reader[input_column].apply(func)
#       6     print('chunk',i,'\n ',reader,'\n=============================\n')
#       7     df = pd.concat([df,reader] , ignore_index=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[19], line 16, in similarity_bert(text)
#      14 with torch.no_grad():
#      15     text_output = model(**inputs)['last_hidden_state'][:, 0]  # Taking the [CLS] token embedding for text
# ---> 16     target_output = model(**inputs)['last_hidden_state'][:, 1]  # Taking the [CLS] token embedding for target
#      18 similarity_score = cosine_similarity(text_output, target_output)[0][0]
#      19 return similarity_score
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:1020, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1011 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1013 embedding_output = self.embeddings(
#    1014     input_ids=input_ids,
#    1015     position_ids=position_ids,
#    (...)
#    1018     past_key_values_length=past_key_values_length,
#    1019 )
# -> 1020 encoder_outputs = self.encoder(
#    1021     embedding_output,
#    1022     attention_mask=extended_attention_mask,
#    1023     head_mask=head_mask,
#    1024     encoder_hidden_states=encoder_hidden_states,
#    1025     encoder_attention_mask=encoder_extended_attention_mask,
#    1026     past_key_values=past_key_values,
#    1027     use_cache=use_cache,
#    1028     output_attentions=output_attentions,
#    1029     output_hidden_states=output_hidden_states,
#    1030     return_dict=return_dict,
#    1031 )
#    1032 sequence_output = encoder_outputs[0]
#    1033 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:610, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     601     layer_outputs = torch.utils.checkpoint.checkpoint(
#     602         create_custom_forward(layer_module),
#     603         hidden_states,
#    (...)
#     607         encoder_attention_mask,
#     608     )
#     609 else:
# --> 610     layer_outputs = layer_module(
#     611         hidden_states,
#     612         attention_mask,
#     613         layer_head_mask,
#     614         encoder_hidden_states,
#     615         encoder_attention_mask,
#     616         past_key_value,
#     617         output_attentions,
#     618     )
#     620 hidden_states = layer_outputs[0]
#     621 if use_cache:
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:495, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     483 def forward(
#     484     self,
#     485     hidden_states: torch.Tensor,
#    (...)
#     492 ) -> Tuple[torch.Tensor]:
#     493     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     494     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 495     self_attention_outputs = self.attention(
#     496         hidden_states,
#     497         attention_mask,
#     498         head_mask,
#     499         output_attentions=output_attentions,
#     500         past_key_value=self_attn_past_key_value,
#     501     )
#     502     attention_output = self_attention_outputs[0]
#     504     # if decoder, the last output is tuple of self-attn cache
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:425, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     415 def forward(
#     416     self,
#     417     hidden_states: torch.Tensor,
#    (...)
#     423     output_attentions: Optional[bool] = False,
#     424 ) -> Tuple[torch.Tensor]:
# --> 425     self_outputs = self.self(
#     426         hidden_states,
#     427         attention_mask,
#     428         head_mask,
#     429         encoder_hidden_states,
#     430         encoder_attention_mask,
#     431         past_key_value,
#     432         output_attentions,
#     433     )
#     434     attention_output = self.output(self_outputs[0], hidden_states)
#     435     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:306, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     304     value_layer = torch.cat([past_key_value[1], value_layer], dim=2)
#     305 else:
# --> 306     key_layer = self.transpose_for_scores(self.key(hidden_states))
#     307     value_layer = self.transpose_for_scores(self.value(hidden_states))
#     309 query_layer = self.transpose_for_scores(mixed_query_layer)
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:272, in BertSelfAttention.transpose_for_scores(self, x)
#     270 new_x_shape = x.size()[:-1] + (self.num_attention_heads, self.attention_head_size)
#     271 x = x.view(new_x_shape)
# --> 272 return x.permute(0, 2, 1, 3)
#
# KeyboardInterrupt:

# %% [markdown]
# # SELECTION 2 - GolVe (glove-wiki-gigaword-100 & -200)

# %%
import gensim.downloader as api
from sklearn.metrics.pairwise import cosine_similarity

# glove-wiki-gigaword-50 : Semantic Similarity: 0.67194796
# glove-wiki-gigaword-200 : Semantic Similarity: 0.55
# glove-wiki-gigaword-100 : Semantic Similarity: 0.63277894

glove_vectors3 = api.load("glove-wiki-gigaword-50")
target = "critical infrastructure"
target_words = target.lower().split()


def similarity_glove(text):
    
    # Tokenize and process text and target embeddings
    text_words = text.lower().split()
    text_embedding = np.mean([glove_vectors3[word] for word in text_words if word in glove_vectors3], axis=0)
    target_embedding = np.mean([glove_vectors3[word] for word in target_words if word in glove_vectors3], axis=0)
    
    similarity_score = cosine_similarity([text_embedding], [target_embedding])[0][0]
    return similarity_score



print(similarity_glove(full_data_clustered['CLEAN TEXT'][1]))

sim_glove = full_data_clustered.sample(5)
sim_glove['CI SCORE GLOVE'] = sim_glove['CLEAN TEXT'].apply(similarity_glove)
sim_glove[['CVE ID','index','CLEAN TEXT','CI SCORE GLOVE']]

# %%
def chunks_scores(csv_input_name, input_column, output_column, csv_output_name, func, chunksize=10000):
    i = 1
    df = pd.DataFrame()
    for reader in pd.read_csv(csv_input_name,  chunksize=chunksize):
        reader[output_column] = reader[input_column].apply(func)
        print('chunk',i,'\n ',reader,'\n=============================\n')
        df = pd.concat([df,reader] , ignore_index=True)
        i = i+1
    return df.to_csv(csv_output_name , index=False)


chunks_scores(
    csv_input_name = 'full_data_clustered_ssim_V3.csv',
    input_column = 'CLEAN TEXT',
    output_column = 'CI SCORE GLOVE 2',
    csv_output_name = 'full_data_clustered_ssim_V4.csv',
    func = similarity_glove,
    chunksize = 10000
)
# Out:
# chunk 1
#                   CVE ID Publish Date Update Date  \
# 0     CVE-2019-1020019   2019-07-29  2019-07-31
# 1     CVE-2019-1020018   2019-07-29  2022-04-18
# 2     CVE-2019-1020016   2019-07-29  2019-08-01
# 3     CVE-2019-1020015   2019-07-29  2021-07-21
# 4     CVE-2019-1020014   2019-07-29  2022-10-06
# ...                ...          ...         ...
# 9995    CVE-2018-19365   2019-03-21  2023-01-20
# 9996    CVE-2018-19362   2019-01-02  2020-08-31
# 9997    CVE-2018-19361   2019-01-02  2020-08-31
# 9998    CVE-2018-19360   2019-01-02  2020-08-31
# 9999    CVE-2018-19300   2019-04-11  2023-04-26
#
#       Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 0                               22413.0      1      79                   XSS
# 1                                3011.0      2     287               Unknown
# 2                                 754.0      3     601               Unknown
# 3                                9380.0      4      20               Unknown
# 4                                 394.0      5     415               Unknown
# ...                                 ...    ...     ...                   ...
# 9995                             5066.0   9996      22            Dir. Trav.
# 9996                              934.0   9997     502               Unknown
# 9997                              934.0   9998     502               Unknown
# 9998                              934.0   9999     502               Unknown
# 9999                             9380.0  10000      20             Exec Code
#
#       Score  Access Complexity  ...     Avail cluster  \
# 0       4.3  Remote     Medium  ...       NaN       0
# 1       7.5  Remote        Low  ...   Partial       2
# 2       5.8  Remote     Medium  ...       NaN       0
# 3       5.0  Remote        Low  ...       NaN       0
# 4       2.1   Local        Low  ...       NaN       0
# ...     ...     ...        ...  ...       ...     ...
# 9995    6.4  Remote        Low  ...   Partial       2
# 9996    7.5  Remote        Low  ...   Partial       2
# 9997    7.5  Remote        Low  ...   Partial       2
# 9998    7.5  Remote        Low  ...   Partial       2
# 9999   10.0  Remote        Low  ...  Complete       2
#
#                                             CVE Summary  \
# 0         invenio-previewer before 1.0.0a12 allows XSS.
# 1     Discourse before 2.3.0 and 2.4.x before 2.4.0....
# 2       ASH-AIO before 2.0.0.3 allows an open redirect.
# 3     graphql-engine (aka Hasura GraphQL Engine) bef...
# 4     docker-credential-helpers before 0.6.3 has a d...
# ...                                                 ...
# 9995  The REST API in Wowza Streaming Engine 4.7.4.0...
# 9996  FasterXML jackson-databind 2.x before 2.9.8 mi...
# 9997  FasterXML jackson-databind 2.x before 2.9.8 mi...
# 9998  FasterXML jackson-databind 2.x before 2.9.8 mi...
# 9999  On D-Link DAP-1530 (A1) before firmware versio...
#
#                                      Vulnerability Name  \
# 0     Failure to Preserve Web Page Structure ('Cross...
# 1                               Improper Authentication
# 2     URL Redirection to Untrusted Site ('Open Redir...
# 3                             Improper Input Validation
# 4                                           Double Free
# ...                                                 ...
# 9995  Improper Limitation of a Pathname to a Restric...
# 9996                  Deserialization of Untrusted Data
# 9997                  Deserialization of Untrusted Data
# 9998                  Deserialization of Untrusted Data
# 9999                          Improper Input Validation
#
#                               Vulnerability Description  \
# 0          The software does not sufficiently valida...
# 1          When an actor claims to have a given iden...
# 2          A web application accepts a user-controll...
# 3          The product does not validate or incorrec...
# 4          The product calls free() twice on the sam...
# ...                                                 ...
# 9995       The software uses external input to const...
# 9996       The application deserializes untrusted da...
# 9997       The application deserializes untrusted da...
# 9998       The application deserializes untrusted da...
# 9999       The product does not validate or incorrec...
#
#                                              CLEAN TEXT cluster_2  CI SCORE  \
# 0     failure preserve web page structure cross site...         1  0.666677
# 1     improper authentication actor claim give ident...         2  0.625171
# 2     url redirection untrusted site open redirect w...         0  0.636100
# 3     improper input validation product validate inc...         0  0.719175
# 4     double free product call free twice memory add...         2  0.707726
# ...                                                 ...       ...       ...
# 9995  improper limitation pathname restricted direct...         0  0.740068
# 9996  deserialization untrusted data application des...         0  0.760590
# 9997  deserialization untrusted data application des...         0  0.751850
# 9998  deserialization untrusted data application des...         0  0.757494
# 9999  improper input validation product validate inc...         2  0.684001
#
#      CI SCORE GLOVE  CI SCORE GLOVE 2
# 0          0.698982          0.620250
# 1          0.632779          0.567375
# 2          0.627934          0.573071
# 3          0.676609          0.614739
# 4          0.695226          0.627228
# ...             ...               ...
# 9995       0.665998          0.595043
# 9996       0.710266          0.649938
# 9997       0.703271          0.645273
# 9998       0.715115          0.652658
# 9999       0.630489          0.569837
#
# [10000 rows x 23 columns]
# =============================
#
# chunk 2
#                  CVE ID Publish Date Update Date  \
# 10000  CVE-2018-19282   2019-04-04  2019-04-09
# 10001  CVE-2018-19276   2019-03-21  2023-03-03
# 10002  CVE-2018-19249   2019-01-03  2019-01-31
# 10003  CVE-2018-19202   2019-04-11  2019-04-12
# 10004  CVE-2018-19201   2019-03-29  2019-04-12
# ...               ...          ...         ...
# 19995   CVE-2020-7327   2020-10-15  2022-06-02
# 19996   CVE-2020-7326   2020-10-15  2020-11-03
# 19997   CVE-2020-7325   2020-09-09  2020-09-14
# 19998   CVE-2020-7324   2020-09-09  2020-09-14
# 19999   CVE-2020-7323   2020-09-09  2022-01-01
#
#        Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 10000                             1320.0  10001     400                   DoS
# 10001                              934.0  10002     502             Exec Code
# 10002                             3011.0  10003     287                Bypass
# 10003                            22413.0  10004      79                   XSS
# 10004                            22413.0  10005      79                   XSS
# ...                                  ...    ...     ...                   ...
# 19995                              143.0  19996     290             Exec Code
# 19996                              143.0  19997     290             Exec Code
# 19997                              893.0  19998      59               Unknown
# 19998                             2264.0  19999     269                Bypass
# 19999                             3011.0  20000     287                Bypass
#
#        Score  Access Complexity  ...     Avail cluster  \
# 10000   10.0  Remote        Low  ...  Complete       2
# 10001   10.0  Remote        Low  ...  Complete       2
# 10002    5.0  Remote        Low  ...       NaN       0
# 10003    4.3  Remote     Medium  ...       NaN       0
# 10004    4.3  Remote     Medium  ...       NaN       0
# ...      ...     ...        ...  ...       ...     ...
# 19995    4.6   Local        Low  ...   Partial       0
# 19996    4.6   Local        Low  ...   Partial       0
# 19997    4.6   Local        Low  ...   Partial       0
# 19998    3.6   Local        Low  ...   Partial       0
# 19999    5.9   Local       High  ...   Partial       2
#
#                                              CVE Summary  \
# 10000  Rockwell Automation PowerFlex 525 AC Drives 5....
# 10001  OpenMRS before 2.24.0 is affected by an Insecu...
# 10002  The Stripe API v1 allows remote attackers to b...
# 10003  A reflected XSS vulnerability in index.php in ...
# 10004  A reflected XSS vulnerability in the ModCP Pro...
# ...                                                  ...
# 19995  Improperly implemented security check in McAfe...
# 19996  Improperly implemented security check in McAfe...
# 19997  Privilege Escalation vulnerability in McAfee M...
# 19998  Improper Access Control vulnerability in McAfe...
# 19999  Authentication Protection Bypass vulnerability...
#
#                                       Vulnerability Name  \
# 10000  Uncontrolled Resource Consumption ('Resource E...
# 10001                  Deserialization of Untrusted Data
# 10002                            Improper Authentication
# 10003  Failure to Preserve Web Page Structure ('Cross...
# 10004  Failure to Preserve Web Page Structure ('Cross...
# ...                                                  ...
# 19995                  Authentication Bypass by Spoofing
# 19996                  Authentication Bypass by Spoofing
# 19997  Improper Link Resolution Before File Access ('...
# 19998                      Improper Privilege Management
# 19999                            Improper Authentication
#
#                                Vulnerability Description  \
# 10000       The software does not properly restrict t...
# 10001       The application deserializes untrusted da...
# 10002       When an actor claims to have a given iden...
# 10003       The software does not sufficiently valida...
# 10004       The software does not sufficiently valida...
# ...                                                  ...
# 19995       This attack-focused weakness is caused by...
# 19996       This attack-focused weakness is caused by...
# 19997       The software attempts to access a file ba...
# 19998       The software does not properly assign, mo...
# 19999       When an actor claims to have a given iden...
#
#                                               CLEAN TEXT cluster_2  CI SCORE  \
# 10000  uncontrolle resource consumption resource exha...         1  0.797584
# 10001  deserialization untrusted data application des...         0  0.736738
# 10002  improper authentication actor claim give ident...         2  0.670637
# 10003  failure preserve web page structure cross site...         1  0.673625
# 10004  failure preserve web page structure cross site...         1  0.670681
# ...                                                  ...       ...       ...
# 19995  authentication bypass spoof attack focus weakn...         0  0.757003
# 19996  authentication bypass spoof attack focus weakn...         0  0.760905
# 19997  improper link resolution file access link foll...         1  0.632459
# 19998  improper privilege management software properl...         2  0.733142
# 19999  improper authentication actor claim give ident...         2  0.705449
#
#       CI SCORE GLOVE  CI SCORE GLOVE 2
# 10000       0.757312          0.691298
# 10001       0.678564          0.620225
# 10002       0.620749          0.555561
# 10003       0.699276          0.621592
# 10004       0.696260          0.617127
# ...              ...               ...
# 19995       0.726860          0.657813
# 19996       0.726025          0.657760
# 19997       0.653542          0.591172
# 19998       0.687867          0.630106
# 19999       0.691766          0.624642
#
# [10000 rows x 23 columns]
# =============================
# chunk 3
#                  CVE ID Publish Date Update Date  \
# 20000   CVE-2020-7322   2020-09-09  2022-05-03
# 20001   CVE-2020-7319   2020-09-09  2022-01-01
# 20002   CVE-2020-7318   2020-10-14  2020-12-23
# 20003   CVE-2020-7317   2020-10-14  2020-10-19
# 20004   CVE-2020-7316   2020-10-07  2020-10-16
# ...               ...          ...         ...
# 29995  CVE-2021-37993   2021-11-02  2022-02-18
# 29996  CVE-2021-37992   2021-11-02  2022-02-18
# 29997  CVE-2021-37991   2021-11-02  2022-02-18
# 29998  CVE-2021-37988   2021-11-02  2022-02-12
# 29999  CVE-2021-37987   2021-11-02  2022-02-12
#
#        Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 20000                              485.0  20001     532               Unknown
# 20001                              893.0  20002      59               Unknown
# 20002                            22413.0  20003      79                   XSS
# 20003                            22413.0  20004      79                   XSS
# 20004                              142.0  20005     428             Exec Code
# ...                                  ...    ...     ...                   ...
# 29995                             3312.0  29996     416               Unknown
# 29996                             4891.0  29997     125               Unknown
# 29997                             1211.0  29998     362               Unknown
# 29998                             3312.0  29999     416               Unknown
# 29999                             3312.0  30000     416               Unknown
#
#        Score         Access Complexity  ...    Avail cluster  \
# 20000    2.1          Local        Low  ...      NaN       0
# 20001    4.6          Local        Low  ...  Partial       0
# 20002    2.3  Local Network     Medium  ...      NaN       0
# 20003    2.3  Local Network     Medium  ...      NaN       0
# 20004    4.6          Local        Low  ...  Partial       0
# ...      ...            ...        ...  ...      ...     ...
# 29995    6.8         Remote     Medium  ...  Partial       2
# 29996    6.8         Remote     Medium  ...  Partial       2
# 29997    5.1         Remote       High  ...  Partial       0
# 29998    6.8         Remote     Medium  ...  Partial       2
# 29999    6.8         Remote     Medium  ...  Partial       2
#
#                                              CVE Summary  \
# 20000  Information Disclosure Vulnerability in McAfee...
# 20001  Improper Access Control vulnerability in McAfe...
# 20002  Cross-Site Scripting vulnerability in McAfee e...
# 20003  Cross-Site Scripting vulnerability in McAfee e...
# 20004  Unquoted service path vulnerability in McAfee ...
# ...                                                  ...
# 29995  Use after free in PDF Accessibility in Google ...
# 29996  Out of bounds read in WebAudio in Google Chrom...
# 29997  Race in V8 in Google Chrome prior to 95.0.4638...
# 29998  Use after free in Profiles in Google Chrome pr...
# 29999  Use after free in Network APIs in Google Chrom...
#
#                                       Vulnerability Name  \
# 20000                 Information Leak Through Log Files
# 20001  Improper Link Resolution Before File Access ('...
# 20002  Failure to Preserve Web Page Structure ('Cross...
# 20003  Failure to Preserve Web Page Structure ('Cross...
# 20004                    Unquoted Search Path or Element
# ...                                                  ...
# 29995                                     Use After Free
# 29996                                 Out-of-bounds Read
# 29997                                     Race Condition
# 29998                                     Use After Free
# 29999                                     Use After Free
#
#                                Vulnerability Description  \
# 20000       Information written to log files can be o...
# 20001       The software attempts to access a file ba...
# 20002       The software does not sufficiently valida...
# 20003       The software does not sufficiently valida...
# 20004       The product uses a search path that conta...
# ...                                                  ...
# 29995       Referencing memory after it has been free...
# 29996       The software reads data past the end, or ...
# 29997       The code requires that certain state shou...
# 29998       Referencing memory after it has been free...
# 29999       Referencing memory after it has been free...
#
#                                               CLEAN TEXT cluster_2  CI SCORE  \
# 20000  information leak log files information write l...         0  0.694883
# 20001  improper link resolution file access link foll...         1  0.643591
# 20002  failure preserve web page structure cross site...         1  0.667198
# 20003  failure preserve web page structure cross site...         1  0.663128
# 20004  unquoted search path element product use searc...         2  0.707472
# ...                                                  ...       ...       ...
# 29995  use free referencing memory free cause program...         0  0.609964
# 29996  bound read software read datum past end beginn...         2  0.682759
# 29997  race condition code require certain state modi...         2  0.762531
# 29998  use free referencing memory free cause program...         0  0.617177
# 29999  use free referencing memory free cause program...         0  0.613323
#
#       CI SCORE GLOVE  CI SCORE GLOVE 2
# 20000       0.689997          0.623201
# 20001       0.670693          0.607394
# 20002       0.694800          0.617468
# 20003       0.691733          0.616456
# 20004       0.668681          0.582289
# ...              ...               ...
# 29995       0.659369          0.586766
# 29996       0.655289          0.584100
# 29997       0.713396          0.660867
# 29998       0.658307          0.588868
# 29999       0.669999          0.594787
#
# [10000 rows x 23 columns]
# =============================
#
# chunk 4
#                  CVE ID Publish Date Update Date  \
# 30000  CVE-2021-37986   2021-11-02  2022-02-12
# 30001  CVE-2021-37985   2021-11-02  2022-02-12
# 30002  CVE-2021-37984   2021-11-02  2022-02-19
# 30003  CVE-2021-37983   2021-11-02  2022-02-18
# 30004  CVE-2021-37982   2021-11-02  2022-02-18
# ...               ...          ...         ...
# 39995  CVE-2020-27267   2021-01-14  2021-01-21
# 39996  CVE-2020-27266   2021-01-19  2021-10-19
# 39997  CVE-2020-27265   2021-01-14  2021-01-21
# 39998  CVE-2020-27264   2021-01-19  2021-01-22
# 39999  CVE-2020-27263   2021-01-14  2021-01-21
#
#        Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 30000                             7611.0  30001     787              Overflow
# 30001                             3312.0  30002     416               Unknown
# 30002                             7611.0  30003     787              Overflow
# 30003                             3312.0  30004     416               Unknown
# 30004                             3312.0  30005     416               Unknown
# ...                                  ...    ...     ...                   ...
# 39995                             7611.0  39996     787              Overflow
# 39996                             3011.0  39997     287                Bypass
# 39997                             7611.0  39998     787    Exec Code Overflow
# 39998                              183.0  39999     330               Unknown
# 39999                             7611.0  40000     787              Overflow
#
#        Score         Access Complexity  ...    Avail cluster  \
# 30000    6.8         Remote     Medium  ...  Partial       2
# 30001    6.8         Remote     Medium  ...  Partial       2
# 30002    6.8         Remote     Medium  ...  Partial       2
# 30003    6.8         Remote     Medium  ...  Partial       2
# 30004    6.8         Remote     Medium  ...  Partial       2
# ...      ...            ...        ...  ...      ...     ...
# 39995    6.4         Remote        Low  ...  Partial       2
# 39996    3.3  Local Network        Low  ...      NaN       0
# 39997    7.5         Remote        Low  ...  Partial       2
# 39998    3.3  Local Network        Low  ...      NaN       0
# 39999    6.4         Remote        Low  ...  Partial       2
#
#                                              CVE Summary  \
# 30000  Heap buffer overflow in Settings in Google Chr...
# 30001  Use after free in V8 in Google Chrome prior to...
# 30002  Heap buffer overflow in PDFium in Google Chrom...
# 30003  Use after free in Dev Tools in Google Chrome p...
# 30004  Use after free in Incognito in Google Chrome p...
# ...                                                  ...
# 39995  KEPServerEX v6.0 to v6.9, ThingWorx Kepware Se...
# 39996  In SOOIL Developments Co., Ltd Diabecare RS, A...
# 39997  KEPServerEX: v6.0 to v6.9, ThingWorx Kepware S...
# 39998  In SOOIL Developments Co., Ltd Diabecare RS, A...
# 39999  KEPServerEX: v6.0 to v6.9, ThingWorx Kepware S...
#
#                         Vulnerability Name  \
# 30000                  Out-of-bounds Write
# 30001                       Use After Free
# 30002                  Out-of-bounds Write
# 30003                       Use After Free
# 30004                       Use After Free
# ...                                    ...
# 39995                  Out-of-bounds Write
# 39996              Improper Authentication
# 39997                  Out-of-bounds Write
# 39998  Use of Insufficiently Random Values
# 39999                  Out-of-bounds Write
#
#                                Vulnerability Description  \
# 30000       The software writes data past the end, or...
# 30001       Referencing memory after it has been free...
# 30002       The software writes data past the end, or...
# 30003       Referencing memory after it has been free...
# 30004       Referencing memory after it has been free...
# ...                                                  ...
# 39995       The software writes data past the end, or...
# 39996       When an actor claims to have a given iden...
# 39997       The software writes data past the end, or...
# 39998       The software may use insufficiently rando...
# 39999       The software writes data past the end, or...
#
#                                               CLEAN TEXT cluster_2  CI SCORE  \
# 30000  bound write software write datum past end begi...         2  0.704163
# 30001  use free referencing memory free cause program...         0  0.607218
# 30002  bound write software write datum past end begi...         2  0.694164
# 30003  use free referencing memory free cause program...         0  0.602718
# 30004  use free referencing memory free cause program...         0  0.601468
# ...                                                  ...       ...       ...
# 39995  bound write software write datum past end begi...         2  0.743728
# 39996  improper authentication actor claim give ident...         2  0.716103
# 39997  bound write software write datum past end begi...         2  0.732795
# 39998  use insufficiently random values software use ...         0  0.747195
# 39999  bound write software write datum past end begi...         2  0.743728
#
#       CI SCORE GLOVE  CI SCORE GLOVE 2
# 30000       0.681094          0.611840
# 30001       0.658318          0.582213
# 30002       0.674826          0.602464
# 30003       0.659367          0.591401
# 30004       0.652416          0.578893
# ...              ...               ...
# 39995       0.702850          0.634953
# 39996       0.688183          0.629798
# 39997       0.686759          0.619720
# 39998       0.695491          0.653860
# 39999       0.702850          0.634953
#
# [10000 rows x 23 columns]
# =============================
# chunk 5
#                  CVE ID Publish Date Update Date  \
# 40000  CVE-2020-27262   2021-01-08  2021-01-14
# 40001  CVE-2020-27261   2021-02-09  2021-02-11
# 40002  CVE-2020-27260   2021-01-08  2021-01-14
# 40003  CVE-2020-27258   2021-01-19  2021-01-22
# 40004  CVE-2020-27256   2021-01-19  2021-01-23
# ...               ...          ...         ...
# 49995  CVE-2022-28126   2022-11-11  2022-11-16
# 49996  CVE-2022-28120   2022-05-05  2022-05-13
# 49997  CVE-2022-28116   2022-04-05  2022-04-12
# 49998  CVE-2022-28115   2022-04-05  2022-04-12
# 49999  CVE-2022-28113   2022-04-15  2022-04-25
#
#        Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 40000                            22413.0  40001      79                   XSS
# 40001                             7611.0  40002     787    Exec Code Overflow
# 40002                              891.0  40003      74               Unknown
# 40003                              855.0  40004     522               Unknown
# 40004                              963.0  40005     798               Unknown
# ...                                  ...    ...     ...                   ...
# 49995                             9380.0  49996      20               Unknown
# 49996                             1591.0  49997     434               Unknown
# 49997                             9554.0  49998      89                   Sql
# 49998                             9554.0  49999      89                   Sql
# 49999                               31.0  50000     565               Unknown
#
#        Score         Access Complexity  ...     Avail cluster  \
# 40000    3.5         Remote     Medium  ...       NaN       0
# 40001    6.8         Remote     Medium  ...   Partial       2
# 40002    2.1          Local        Low  ...       NaN       0
# 40003    3.3  Local Network        Low  ...       NaN       0
# 40004    4.6          Local        Low  ...   Partial       0
# ...      ...            ...        ...  ...       ...     ...
# 49995    0.0        Unknown    Unknown  ...   Unknown       1
# 49996    7.5         Remote        Low  ...   Partial       2
# 49997    7.5         Remote        Low  ...   Partial       2
# 49998    7.5         Remote        Low  ...   Partial       2
# 49999    9.0         Remote        Low  ...  Complete       2
#
#                                              CVE Summary  \
# 40000  Innokas Yhtymä Oy Vital Signs Monitor VC150 pr...
# 40001  The Omron CX-One Version 4.60 and prior is vul...
# 40002  Innokas Yhtymä Oy Vital Signs Monitor VC150 pr...
# 40003  In SOOIL Developments Co., Ltd Diabecare RS, A...
# 40004  In SOOIL Developments Co., Ltd Diabecare RS, A...
# ...                                                  ...
# 49995  Improper input validation in some Intel(R) XMM...
# 49996  Beijing Runnier Network Technology Co., Ltd Op...
# 49997  Online Banking System v1.0 was discovered to c...
# 49998  Online Sports Complex Booking v1.0 was discove...
# 49999  An issue in upload.csp of FANTEC GmbH MWiD25-D...
#
#                                       Vulnerability Name  \
# 40000  Failure to Preserve Web Page Structure ('Cross...
# 40001                                Out-of-bounds Write
# 40002  Failure to Sanitize Data into a Different Plan...
# 40003               Insufficiently Protected Credentials
# 40004                      Use of Hard-coded Credentials
# ...                                                  ...
# 49995                          Improper Input Validation
# 49996    Unrestricted Upload of File with Dangerous Type
# 49997  Improper Sanitization of Special Elements used...
# 49998  Improper Sanitization of Special Elements used...
# 49999  Reliance on Cookies without Validation and Int...
#
#                                Vulnerability Description  \
# 40000       The software does not sufficiently valida...
# 40001       The software writes data past the end, or...
# 40002       The software fails to adequately filter u...
# 40003       This weakness occurs when the application...
# 40004       The software contains hard-coded credenti...
# ...                                                  ...
# 49995       The product does not validate or incorrec...
# 49996       The software allows the attacker to uploa...
# 49997       The software constructs all or part of an...
# 49998       The software constructs all or part of an...
# 49999       The application relies on the existence o...
#
#                                               CLEAN TEXT cluster_2  CI SCORE  \
# 40000  failure preserve web page structure cross site...         1  0.669445
# 40001  bound write software write datum past end begi...         2  0.696788
# 40002  failure sanitize datum different plane injecti...         2  0.749109
# 40003  insufficiently protected credential weakness o...         2  0.725553
# 40004  use hard code credential software contain hard...         0  0.743597
# ...                                                  ...       ...       ...
# 49995  improper input validation product validate inc...         0  0.744751
# 49996  unrestricted upload file dangerous type softwa...         1  0.706073
# 49997  improper sanitization special elements sql com...         0  0.721730
# 49998  improper sanitization special elements sql com...         0  0.719771
# 49999  reliance cookies validation integrity checking...         0  0.703378
#
#       CI SCORE GLOVE  CI SCORE GLOVE 2
# 40000       0.697140          0.622554
# 40001       0.652096          0.585647
# 40002       0.696057          0.647557
# 40003       0.655928          0.611011
# 40004       0.719013          0.647795
# ...              ...               ...
# 49995       0.687584          0.634589
# 49996       0.654919          0.592215
# 49997       0.636244          0.579133
# 49998       0.634166          0.574561
# 49999       0.637357          0.577457
#
# [10000 rows x 23 columns]
# =============================
#
# chunk 6
#                  CVE ID Publish Date Update Date  \
# 50000  CVE-2022-28111   2022-05-04  2022-12-12
# 50001  CVE-2022-28110   2022-05-10  2022-05-17
# 50002  CVE-2022-28106   2022-05-20  2022-05-26
# 50003  CVE-2022-28105   2022-05-20  2022-05-26
# 50004  CVE-2022-28104   2022-05-20  2022-06-02
# ...               ...          ...         ...
# 59995  CVE-2021-32415   2022-12-13  2022-12-15
# 59996  CVE-2021-32161   2022-04-11  2022-04-15
# 59997  CVE-2021-32160   2022-04-11  2022-04-15
# 59998  CVE-2021-32158   2022-04-11  2022-04-15
# 59999  CVE-2021-32157   2022-04-11  2022-04-14
#
#        Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 50000                             9554.0  50001      89                   Sql
# 50001                             9554.0  50002      89                   Sql
# 50002                             3011.0  50003     287               Unknown
# 50003                             9554.0  50004      89                   Sql
# 50004                             1591.0  50005     434               Unknown
# ...                                  ...    ...     ...                   ...
# 59995                             2264.0  59996     269               Unknown
# 59996                            22413.0  59997      79                   XSS
# 59997                            22413.0  59998      79                   XSS
# 59998                            22413.0  59999      79                   XSS
# 59999                            22413.0  60000      79                   XSS
#
#        Score   Access Complexity  ...    Avail cluster  \
# 50000    7.5   Remote        Low  ...  Partial       2
# 50001    7.5   Remote        Low  ...  Partial       2
# 50002    7.5   Remote        Low  ...  Partial       2
# 50003    7.5   Remote        Low  ...  Partial       2
# 50004    7.5   Remote        Low  ...  Partial       2
# ...      ...      ...        ...  ...      ...     ...
# 59995    0.0  Unknown    Unknown  ...  Unknown       1
# 59996    4.3   Remote     Medium  ...      NaN       0
# 59997    4.3   Remote     Medium  ...      NaN       0
# 59998    4.3   Remote     Medium  ...      NaN       0
# 59999    6.8   Remote     Medium  ...  Partial       2
#
#                                              CVE Summary  \
# 50000  MyBatis PageHelper v1.x.x-v3.7.0 v4.0.0-v5.0.0...
# 50001  Hotel Management System v1.0 was discovered to...
# 50002  Online Sports Complex Booking System v1.0 was ...
# 50003  Online Sports Complex Booking System v1.0 was ...
# 50004  Foxit PDF Editor v11.3.1 was discovered to con...
# ...                                                  ...
# 59995  EXEMSI MSI Wrapper Versions prior to 10.0.50 a...
# 59996  A Cross-Site Scripting (XSS) vulnerability exi...
# 59997  A Cross-Site Scripting (XSS) vulnerability exi...
# 59998  A Cross-Site Scripting (XSS) vulnerability exi...
# 59999  A Cross-Site Scripting (XSS) vulnerability exi...
#
#                                       Vulnerability Name  \
# 50000  Improper Sanitization of Special Elements used...
# 50001  Improper Sanitization of Special Elements used...
# 50002                            Improper Authentication
# 50003  Improper Sanitization of Special Elements used...
# 50004    Unrestricted Upload of File with Dangerous Type
# ...                                                  ...
# 59995                      Improper Privilege Management
# 59996  Failure to Preserve Web Page Structure ('Cross...
# 59997  Failure to Preserve Web Page Structure ('Cross...
# 59998  Failure to Preserve Web Page Structure ('Cross...
# 59999  Failure to Preserve Web Page Structure ('Cross...
#
#                                Vulnerability Description  \
# 50000       The software constructs all or part of an...
# 50001       The software constructs all or part of an...
# 50002       When an actor claims to have a given iden...
# 50003       The software constructs all or part of an...
# 50004       The software allows the attacker to uploa...
# ...                                                  ...
# 59995       The software does not properly assign, mo...
# 59996       The software does not sufficiently valida...
# 59997       The software does not sufficiently valida...
# 59998       The software does not sufficiently valida...
# 59999       The software does not sufficiently valida...
#
#                                               CLEAN TEXT cluster_2  CI SCORE  \
# 50000  improper sanitization special elements sql com...         0  0.715381
# 50001  improper sanitization special elements sql com...         0  0.714866
# 50002  improper authentication actor claim give ident...         2  0.692324
# 50003  improper sanitization special elements sql com...         0  0.724633
# 50004  unrestricted upload file dangerous type softwa...         2  0.603704
# ...                                                  ...       ...       ...
# 59995  improper privilege management software properl...         2  0.744035
# 59996  failure preserve web page structure cross site...         1  0.668262
# 59997  failure preserve web page structure cross site...         1  0.664580
# 59998  failure preserve web page structure cross site...         1  0.666464
# 59999  failure preserve web page structure cross site...         1  0.672668
#
#       CI SCORE GLOVE  CI SCORE GLOVE 2
# 50000       0.625360          0.565042
# 50001       0.628001          0.566209
# 50002       0.637006          0.572857
# 50003       0.640019          0.579990
# 50004       0.542535          0.484302
# ...              ...               ...
# 59995       0.649676          0.568937
# 59996       0.697356          0.616096
# 59997       0.696743          0.617048
# 59998       0.687314          0.610177
# 59999       0.702551          0.623399
#
# [10000 rows x 23 columns]
# =============================
# chunk 7
#                  CVE ID Publish Date Update Date  \
# 60000  CVE-2021-32040   2022-04-12  2023-02-03
# 60001  CVE-2021-32039   2022-01-20  2022-01-26
# 60002  CVE-2021-32036   2022-02-04  2022-02-09
# 60003  CVE-2021-32010   2022-05-04  2022-05-11
# 60004  CVE-2021-32009   2022-03-11  2022-03-18
# ...               ...          ...         ...
# 61693  CVE-2008-10001   2022-03-28  2022-04-08
# 61694  CVE-2007-20001   2022-02-06  2022-09-01
# 61695  CVE-2005-10001   2022-03-28  2022-04-08
# 61696   CVE-2003-5003   2022-03-28  2022-04-06
# 61697   CVE-2003-5002   2022-03-28  2022-04-06
#
#        Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 60000                             7611.0  60001     787              Overflow
# 60001                              855.0  60002     522               Unknown
# 60002                              530.0  60003     770                   DoS
# 60003                              323.0  60004     326               Unknown
# 60004                            22413.0  60005      79                   XSS
# ...                                  ...    ...     ...                   ...
# 61693                            22413.0  61694      79                   XSS
# 61694                             1320.0  61695     400                   DoS
# 61695                              754.0  61696     601               Unknown
# 61696                            22413.0  61697      79                   XSS
# 61697                              403.0  61698     319               Unknown
#
#        Score  Access Complexity  ...    Avail cluster  \
# 60000    5.0  Remote        Low  ...  Partial       0
# 60001    2.1   Local        Low  ...      NaN       0
# 60002    5.5  Remote        Low  ...  Partial       0
# 60003    6.8  Remote     Medium  ...  Partial       2
# 60004    4.3  Remote     Medium  ...      NaN       0
# ...      ...     ...        ...  ...      ...     ...
# 61693    4.3  Remote     Medium  ...      NaN       0
# 61694    5.0  Remote        Low  ...  Partial       0
# 61695    5.8  Remote     Medium  ...      NaN       0
# 61696    4.3  Remote     Medium  ...      NaN       0
# 61697    5.0  Remote        Low  ...      NaN       0
#
#                                              CVE Summary  \
# 60000  It may be possible to have an extremely long a...
# 60001  Users with appropriate file access may be able...
# 60002  An authenticated user without any specific aut...
# 60003  Inadequate Encryption Strength vulnerability i...
# 60004  Cross-site Scripting (XSS) vulnerability in fi...
# ...                                                  ...
# 61693  ** UNSUPPORTED WHEN ASSIGNED ** A vulnerabilit...
# 61694  A flaw was found in StarWind iSCSI target. An ...
# 61695  ** UNSUPPORTED WHEN ASSIGNED ** A vulnerabilit...
# 61696  ** UNSUPPORTED WHEN ASSIGNED ** A vulnerabilit...
# 61697  ** UNSUPPORTED WHEN ASSIGNED ** A vulnerabilit...
#
#                                       Vulnerability Name  \
# 60000                                Out-of-bounds Write
# 60001               Insufficiently Protected Credentials
# 60002  Allocation of Resources Without Limits or Thro...
# 60003                     Inadequate Encryption Strength
# 60004  Failure to Preserve Web Page Structure ('Cross...
# ...                                                  ...
# 61693  Failure to Preserve Web Page Structure ('Cross...
# 61694  Uncontrolled Resource Consumption ('Resource E...
# 61695  URL Redirection to Untrusted Site ('Open Redir...
# 61696  Failure to Preserve Web Page Structure ('Cross...
# 61697    Cleartext Transmission of Sensitive Information
#
#                                Vulnerability Description  \
# 60000       The software writes data past the end, or...
# 60001       This weakness occurs when the application...
# 60002       The software allocates a reusable resourc...
# 60003       The software stores or transmits sensitiv...
# 60004       The software does not sufficiently valida...
# ...                                                  ...
# 61693       The software does not sufficiently valida...
# 61694       The software does not properly restrict t...
# 61695       A web application accepts a user-controll...
# 61696       The software does not sufficiently valida...
# 61697       The software transmits sensitive or secur...
#
#                                               CLEAN TEXT cluster_2  CI SCORE  \
# 60000  bound write software write datum past end begi...         2  0.717167
# 60001  insufficiently protected credential weakness o...         0  0.696908
# 60002  allocation resources limits throttling softwar...         2  0.812514
# 60003  inadequate encryption strength software store ...         0  0.766833
# 60004  failure preserve web page structure cross site...         1  0.670456
# ...                                                  ...       ...       ...
# 61693  failure preserve web page structure cross site...         1  0.706891
# 61694  uncontrolle resource consumption resource exha...         1  0.789261
# 61695  url redirection untrusted site open redirect w...         0  0.696738
# 61696  failure preserve web page structure cross site...         1  0.711290
# 61697  cleartext transmission sensitive information s...         1  0.804882
#
#       CI SCORE GLOVE  CI SCORE GLOVE 2
# 60000       0.687022          0.629178
# 60001       0.614830          0.562164
# 60002       0.754997          0.688685
# 60003       0.735725          0.674942
# 60004       0.691132          0.612213
# ...              ...               ...
# 61693       0.713690          0.645094
# 61694       0.747740          0.679483
# 61695       0.670062          0.621229
# 61696       0.719332          0.651999
# 61697       0.735057          0.689226
#
# [1698 rows x 23 columns]
# =============================

# %% [markdown]
# ## Final data

# %%
full_data_clustered_ssim_V3 = pd.read_csv('full_data_clustered_ssim_V3.csv')
full_data_clustered_ssim_V3 = full_data_clustered_ssim_V3.replace(np.nan,'None')

# %%
full_data_clustered_ssim_V3
# Out:
#                  CVE ID Publish Date Update Date  \
# 0      CVE-2019-1020019   2019-07-29  2019-07-31
# 1      CVE-2019-1020018   2019-07-29  2022-04-18
# 2      CVE-2019-1020016   2019-07-29  2019-08-01
# 3      CVE-2019-1020015   2019-07-29  2021-07-21
# 4      CVE-2019-1020014   2019-07-29  2022-10-06
# ...                 ...          ...         ...
# 61693    CVE-2008-10001   2022-03-28  2022-04-08
# 61694    CVE-2007-20001   2022-02-06  2022-09-01
# 61695    CVE-2005-10001   2022-03-28  2022-04-08
# 61696     CVE-2003-5003   2022-03-28  2022-04-06
# 61697     CVE-2003-5002   2022-03-28  2022-04-06
#
#        Number Of Related Vulnerabilities  index  CWE ID Vulnerability Type(s)  \
# 0                                22413.0      1      79                   XSS
# 1                                 3011.0      2     287               Unknown
# 2                                  754.0      3     601               Unknown
# 3                                 9380.0      4      20               Unknown
# 4                                  394.0      5     415               Unknown
# ...                                  ...    ...     ...                   ...
# 61693                            22413.0  61694      79                   XSS
# 61694                             1320.0  61695     400                   DoS
# 61695                              754.0  61696     601               Unknown
# 61696                            22413.0  61697      79                   XSS
# 61697                              403.0  61698     319               Unknown
#
#        Score  Access Complexity  ...    Avail cluster  \
# 0        4.3  Remote     Medium  ...     None       0
# 1        7.5  Remote        Low  ...  Partial       2
# 2        5.8  Remote     Medium  ...     None       0
# 3        5.0  Remote        Low  ...     None       0
# 4        2.1   Local        Low  ...     None       0
# ...      ...     ...        ...  ...      ...     ...
# 61693    4.3  Remote     Medium  ...     None       0
# 61694    5.0  Remote        Low  ...  Partial       0
# 61695    5.8  Remote     Medium  ...     None       0
# 61696    4.3  Remote     Medium  ...     None       0
# 61697    5.0  Remote        Low  ...     None       0
#
#                                              CVE Summary  \
# 0          invenio-previewer before 1.0.0a12 allows XSS.
# 1      Discourse before 2.3.0 and 2.4.x before 2.4.0....
# 2        ASH-AIO before 2.0.0.3 allows an open redirect.
# 3      graphql-engine (aka Hasura GraphQL Engine) bef...
# 4      docker-credential-helpers before 0.6.3 has a d...
# ...                                                  ...
# 61693  ** UNSUPPORTED WHEN ASSIGNED ** A vulnerabilit...
# 61694  A flaw was found in StarWind iSCSI target. An ...
# 61695  ** UNSUPPORTED WHEN ASSIGNED ** A vulnerabilit...
# 61696  ** UNSUPPORTED WHEN ASSIGNED ** A vulnerabilit...
# 61697  ** UNSUPPORTED WHEN ASSIGNED ** A vulnerabilit...
#
#                                       Vulnerability Name  \
# 0      Failure to Preserve Web Page Structure ('Cross...
# 1                                Improper Authentication
# 2      URL Redirection to Untrusted Site ('Open Redir...
# 3                              Improper Input Validation
# 4                                            Double Free
# ...                                                  ...
# 61693  Failure to Preserve Web Page Structure ('Cross...
# 61694  Uncontrolled Resource Consumption ('Resource E...
# 61695  URL Redirection to Untrusted Site ('Open Redir...
# 61696  Failure to Preserve Web Page Structure ('Cross...
# 61697    Cleartext Transmission of Sensitive Information
#
#                                Vulnerability Description  \
# 0           The software does not sufficiently valida...
# 1           When an actor claims to have a given iden...
# 2           A web application accepts a user-controll...
# 3           The product does not validate or incorrec...
# 4           The product calls free() twice on the sam...
# ...                                                  ...
# 61693       The software does not sufficiently valida...
# 61694       The software does not properly restrict t...
# 61695       A web application accepts a user-controll...
# 61696       The software does not sufficiently valida...
# 61697       The software transmits sensitive or secur...
#
#                                               CLEAN TEXT cluster_2  CI SCORE  \
# 0      failure preserve web page structure cross site...         1  0.666677
# 1      improper authentication actor claim give ident...         2  0.625171
# 2      url redirection untrusted site open redirect w...         0  0.636100
# 3      improper input validation product validate inc...         0  0.719175
# 4      double free product call free twice memory add...         2  0.707726
# ...                                                  ...       ...       ...
# 61693  failure preserve web page structure cross site...         1  0.706891
# 61694  uncontrolle resource consumption resource exha...         1  0.789261
# 61695  url redirection untrusted site open redirect w...         0  0.696738
# 61696  failure preserve web page structure cross site...         1  0.711290
# 61697  cleartext transmission sensitive information s...         1  0.804882
#
#       CI SCORE GLOVE  CI SCORE GLOVE 2
# 0           0.698982          0.620250
# 1           0.632779          0.567375
# 2           0.627934          0.573071
# 3           0.676609          0.614739
# 4           0.695226          0.627228
# ...              ...               ...
# 61693       0.713690          0.645094
# 61694       0.747740          0.679483
# 61695       0.670062          0.621229
# 61696       0.719332          0.651999
# 61697       0.735057          0.689226
#
# [61698 rows x 23 columns]
